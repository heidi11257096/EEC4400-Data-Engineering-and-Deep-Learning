# %%
# import libraries

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense

import numpy as np
from numpy import array
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# define input sequence
raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# choose a number of time steps
seq_len = 3

# choose number of future time steps to predict
n_steps = 2

# %%
def split_sequence(sequence, seq_len, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + seq_len
		# check if we are beyond the sequence
		if end_ix + n_steps > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:end_ix+n_steps]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# split into sequences
# Understand and use the split_sequence function in the cell above to split the raw data into sequences
seq_X, seq_Y =  # [WriteCode] ...

# Print the sequence X and Y values generated (result must look like desired output mentioned in part (a) of Q3)
# [WriteCode] ...

# %%
# Reshape seq_X such that it can be fed as input to the model. 
# TensorFlow models require the input shape to be of the form: (no. of sequences, sequence length, no. of features).

X = seq_X.reshape((seq_X.shape[0], seq_X.shape[1], 1))
Y = seq_Y


print(X.shape, Y.shape)

# %%
# Define the RNN network with TF keras with 1 hidden layer containing 50 nodes and ReLU activation and 1 output layer with no. of nodes = n_steps
# Use Adam optimizer and MSE loss

model = # [WriteCode] ...

# Observe the number of model parameters used for the given RNN architecture using summary()
print(model.summary())

# Train model with epochs = 200 using model.fit()

history = # [WriteCode] ...

# %%
# Define the RNN network with TF keras with 1 hidden layer containing 50 nodes and ReLU activation, followed by batch normalization layer
# and 1 output layer with no. of nodes = n_steps
# Use Adam optimizer and MSE loss

model = # [WriteCode] ...

# Observe the number of model parameters used for the given RNN + BN architecture using summary()
print(model.summary())

# Train model with epochs = 200 using model.fit()

history1 = # [WriteCode] ...

# %%
# Test Prediction using RNN +BN model

X_test = array([70, 80, 90])

# Use X_test to get prediction using model.predict and print the predicted results
# [WriteCode] ...

# %%
# Define the LSTM network with TF keras with 1 hidden layer containing 50 nodes and ReLU activation and 1 output layer with no. of nodes = n_steps
# Use Adam optimizer and MSE loss

model = # [WriteCode] ...

# Observe the number of model parameters used for the given LSTM architecture using summary()
print(model.summary())

# Train model with epochs = 200 using model.fit()

history2 = # [WriteCode] ...

# %%
# Test Prediction using LSTM model

X_test = array([70, 80, 90])

# Use X_test to get prediction using model.predict and print the predicted results
# [WriteCode] ...

# %%
# plot training loss of simple RNN and RNN + BN models
 
plt.plot(history.history["loss"])
plt.plot(history1.history["loss"])
plt.legend(("RNN", "Batch"))

# %%
# plot training loss of simple RNN and LSTM models

plt.plot(history.history["loss"])
plt.plot(history2.history["loss"])
plt.legend(("RNN", "LSTM"))
plt.ylim((0, 300))

# %%
keras.backend.clear_session()
