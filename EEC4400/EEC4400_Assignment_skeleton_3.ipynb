# %%
Student_1 = '邓希尧' #@param {type:"string"}  Name of student 1
Student_2 = '' #@param {type:"string"}  Name of student 2
Student_3 = '' #@param {type:"string"}  Name of student 3
Student_4 = '' #@param {type:"string"}  Name of student 4
print(Student_1)
# Out:
# 邓希尧

# %% [markdown]
# # Overview
#
# This is the skeleton code file for the EEC4400 assignment. Replace the `XX`. in the name of this Jupyter notebook with your group number (this is important for correct marks to be awarded to your group). Fill in the blank cells below with the necessary code (you should work on this Jupyter notebook section by section). At the end, the entire Jupyter notebook should generate all the required results and execute without error.
#
# The text above the blank cells provides information on the functionality that needs to be implemented. You need to write Python code at places indicated by `[WriteCode]`

# %% [markdown]
# ## Install and Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "5" 
import time
import numpy as np
import random
from collections import deque

import gymnasium as gym

# %% [markdown]
# # Background

# %% [markdown]
# ## Environment Exploration: Cart-Pole
#
# The **Cart-Pole environment** is a classic reinforcement learning problem where a pole is attached by an un-actuated joint to a cart. The cart moves along a frictionless track, and the goal is to balance the pole upright by applying forces to move the cart left or right.
#
# <img src="https://gymnasium.farama.org/_images/cart_pole.gif" width="400">
#
# Below is a breakdown of the base Cart-Pole environment:

# %% [markdown]
# #### - **Observation Space (*s*)**
# The observation is represented as a `ndarray` of shape `(4,)`, corresponding to:
# - **Cart Position**: Horizontal location of the cart.
# - **Cart Velocity**: Speed of the cart along the track.
# - **Pole Angle**: Angular position of the pole relative to vertical.
# - **Pole Angular Velocity**: Speed at which the pole angle changes.
#
# The observations are initialized with uniformly random values in the range `(-0.05, 0.05)`.

# %% [markdown]
# #### - **Action Space (*a*)**
# The action is a discrete value (`0` or `1`) indicating the direction of the force applied to the cart:
# - `0`: Push the cart to the left.
# - `1`: Push the cart to the right.

# %% [markdown]
# #### - **Reward Function (*r*)**
# The agent receives a reward of `+1` for each time step it successfully keeps the pole upright. The maximum achievable reward in a single episode is `500`.

# %% [markdown]
# #### - **Episode Termination (*isDone*)**
# An episode ends if any of the following conditions occur:
# 1. **Pole Angle** exceeds `±12°`.
# 2. **Cart Position** exceeds `±2.4` (the cart reaches the edge of the track).
# 3. **Truncation**: The episode reaches the maximum length of `500 steps`.

# %% [markdown]
# ## Getting Familiar with Basic Gymnasium Usage
#
# Let's observe how to interact with a Gymnasium environment.

# %% [markdown]
# The classic “agent-environment loop” pictured below is a simplified representation of reinforcement learning that Gymnasium implements.
#
# ![agt-env.png](attachment:d805e642-400b-4fa6-b924-f8fcc8ed6f53.png)
#
# The following section represents a simple episode of this loop, we will:
#
# 1. Import the base Cart-Pole environment from the gymnasium library and explore its functionality.
#
# 2. Apply modifications to make the environment more challenging by adjusting the pole's dynamics and introducing stochastic forces.
#
# 3. Sample random actions to control the cart-pole.
#
# These steps will help us understand how the environment behaves under different conditions and prepare us for implementing reinforcement learning agents in later sections.

# %%
import warnings
warnings.filterwarnings('ignore')

# Import and Explore the Environment
print("\n--- Exploring the Base Environment ---")
env = gym.make("CartPole-v1")
observation, info = env.reset()

# Print information about the environment
print(f"Initial Observation: {observation}") #小车位置 (Cart Position)小车速度 (Cart Velocity)杆子角度 (Pole Angle)杆尖速度 (Pole Angular Velocity)
print(f"Action Space: {env.action_space}")  # Discrete actions: 0 (left), 1 (right)
print(f"Observation Space: {env.observation_space}")  # State variables: cart position, etc.
# Out:
# --- Exploring the Base Environment ---
# Initial Observation: [ 0.00641255 -0.03566993 -0.00750061  0.02141522]
# Action Space: Discrete(2)
# Observation Space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %% [markdown]
# # Define Helper Functions

# %% [markdown]
# ## Plotting Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# --- 设置一个美观的绘图风格 ---
# 'seaborn-v0_8-whitegrid' 是一个非常流行的风格，带有网格，看起来很清爽
plt.style.use('seaborn-v0_8-whitegrid')


def plot_eval_rwd_mean(eval_mean_list):
    """
    绘制评估阶段的平均奖励随时间变化的曲线。

    Args:
        eval_mean_list (list or np.ndarray): 包含每次评估的平均奖励的列表。
    """
    # 创建一个图形和坐标轴，设置图形大小
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # x轴坐标就是评估的次数
    x_axis = range(len(eval_mean_list))
    
    # 绘制曲线
    ax.plot(x_axis, eval_mean_list, 
            color='dodgerblue',          # 使用一种好看的蓝色
            marker='o',                  # 在每个数据点上加个圆圈标记
            linestyle='-',               # 使用实线连接
            linewidth=2,                 # 线条宽度
            markersize=5,                # 标记大小
            label='Mean Reward')         # 图例标签
            
    # 设置标题和坐标轴标签，并增加字体大小
    ax.set_title('Evaluation Reward Mean Over Time', fontsize=16)
    ax.set_xlabel('Evaluation Step', fontsize=12)
    ax.set_ylabel('Mean Reward', fontsize=12)
    
    # 显示图例
    ax.legend()
    
    # 显示图形
    plt.tight_layout()  # 调整布局以防止标签重叠
    plt.show()


def plot_eval_rwd_var(eval_var_list):
    """
    绘制评估阶段的奖励方差随时间变化的曲线。

    Args:
        eval_var_list (list or np.ndarray): 包含每次评估的奖励方差的列表。
    """
    # 创建一个图形和坐标轴
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # x轴坐标
    x_axis = range(len(eval_var_list))
    
    # 绘制曲线
    ax.plot(x_axis, eval_var_list, 
            color='forestgreen',         # 使用绿色
            marker='s',                  # 使用方形标记
            linestyle='--',              # 使用虚线
            linewidth=2,
            markersize=5,
            label='Reward Variance')
            
    # 设置标题和标签
    ax.set_title('Evaluation Reward Variance Over Time', fontsize=16)
    ax.set_xlabel('Evaluation Step', fontsize=12)
    ax.set_ylabel('Reward Variance', fontsize=12)
    
    # 显示图例
    ax.legend()
    
    # 显示图形
    plt.tight_layout()
    plt.show()


def plot_smoothed_training_rwd(train_rwd_list, window_size=20):
    """
    使用移动平均法绘制平滑后的训练奖励曲线。
    同时将原始的、未平滑的奖励作为背景，以提供对比。

    Args:
        train_rwd_list (list or np.ndarray): 包含每个训练回合总奖励的列表。
        window_size (int): 移动平均的窗口大小。
    """
    if len(train_rwd_list) < window_size:
        print(f"Warning: train_rwd_list has fewer elements ({len(train_rwd_list)}) than window_size ({window_size})." 
              " Cannot compute moving average.")
        return

    # 创建一个图形和坐标轴
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # 1. 绘制原始的训练奖励，使用较浅的颜色和透明度作为背景
    ax.plot(train_rwd_list, 
            color='lightgray', 
            alpha=0.6, 
            label='Raw Reward per Episode')
            
    # 2. 计算移动平均值
    # np.convolve 是一个高效计算移动平均的方法
    # mode='valid' 确保我们只在窗口完全覆盖数据时才计算平均值
    smoothed_rewards = np.convolve(train_rwd_list, np.ones(window_size)/window_size, mode='valid')
    
    # 3. 绘制平滑后的奖励曲线，使用醒目的颜色
    # 注意：平滑后的数据点数会减少，x轴需要对齐
    smoothed_x_axis = np.arange(window_size - 1, len(train_rwd_list))
    ax.plot(smoothed_x_axis, smoothed_rewards, 
            color='crimson',             # 使用深红色
            linewidth=2.5, 
            label=f'Smoothed Reward (Window Size = {window_size})')
            
    # 设置标题和标签
    ax.set_title('Smoothed Training Rewards Over Episodes', fontsize=16)
    ax.set_xlabel('Episode', fontsize=12)
    ax.set_ylabel('Total Reward', fontsize=12)
    
    # 显示图例
    ax.legend()
    
    # 显示图形
    plt.tight_layout()
    plt.show()

# %%
# --- 测试绘图函数 ---
    # 生成一些假的示例数据
    # 评估数据（通常点比较少）
fake_eval_mean = np.array([10, 25, 50, 80, 120, 150, 180, 200, 210, 205])
fake_eval_var = np.array([5, 10, 20, 15, 25, 30, 25, 20, 15, 10])

# 训练数据（通常点很多，波动大）
base_rewards = np.linspace(10, 200, 500)
noise = np.random.normal(0, 30, 500)
fake_training_rewards = base_rewards + noise

print("--- Plotting Evaluation Mean Reward ---")
plot_eval_rwd_mean(fake_eval_mean)

print("\n--- Plotting Evaluation Reward Variance ---")
plot_eval_rwd_var(fake_eval_var)

print("\n--- Plotting Smoothed Training Reward ---")
plot_smoothed_training_rwd(fake_training_rewards, window_size=20)
# Out:
# --- Plotting Evaluation Mean Reward ---
# --- Plotting Evaluation Reward Variance ---
# --- Plotting Smoothed Training Reward ---

# %% [markdown]
# ## Evaluation Function
#
# Evaluate the learnt policy by running 5 evaluation episodes and computing the average and variance of rewards collected.

# %%
def evaluation(model, max_timesteps=500):
    eval_env = gym.make("CartPole-v1")
    state_size = eval_env.observation_space.shape[0] # Number of observations (CartPole)
    action_size = eval_env.action_space.n            # Number of possible actions
    eval_reward = []

    for i in range (5):
        round_reward = 0
        state, _ = eval_env.reset()
        state = np.reshape(state, [1, state_size])

        for i in range(max_timesteps):
            action = np.argmax(model.predict(state, verbose=0)[0])               #verbose=0 to 用来设置日志静默模式(其他可选值为1进度条模式，2精简日志模式)                                                                                    
            next_state, reward, terminated, truncated, _ = eval_env.step(action) #argmax返回最大值的索引
            next_state = np.reshape(next_state, [1, state_size])

            round_reward += reward
            state = next_state

            if terminated or truncated:
                eval_reward.append(round_reward)
                break

    eval_env.close()

    eval_reward_mean = np.sum(eval_reward)/len(eval_reward)
    eval_reward_var = np.var(eval_reward)

    return eval_reward_mean, eval_reward_var

# %% [markdown]
# # Setting up Tensorboard

# %%
# def get_run_logdir(k):
#     root_logdir = os.path.join(os.curdir, "eec4400_logs", k) #curdir 获取当前工作目录
#     run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S") #strftime() 根据指定的格式，将当前时间格式化成一个字符串
#     return os.path.join(root_logdir, run_id)
def get_run_logdir(k):
    # 使用 os.getcwd() 获取当前工作目录的实际路径，而不是 os.curdir (返回 '.')
    root_logdir = os.path.join(os.getcwd(), "eec4400_logs", k)
    
    # 确保所有父目录都存在
    os.makedirs(root_logdir, exist_ok=True)
    
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    logdir = os.path.join(root_logdir, run_id)
    
    # 确保最终的运行目录也存在
    os.makedirs(logdir, exist_ok=True)
    
    # 转换为绝对路径并规范化
    logdir = os.path.abspath(logdir)
    
    # 验证目录确实存在
    if not os.path.isdir(logdir):
        raise ValueError(f"无法创建或访问目录: {logdir}")
    
    print(f"TensorBoard log directory: {logdir}")
    return logdir

# %% [markdown]
# # Initialize Parameters

# %%
# Use the following set of NN hyperparameters for ALL FOUR baseline policies
lr =  0.00025        #@param {type:"number"}               # learning rate
epoch =  1     #@param {type:"number"}               # epochs
episode = 250  #@param {type:"number"}               # episodes

epsilon = 1           #@param {type:"number"}     # Starting exploration rate
epsilon_min = 0.01    #@param {type:"number"}     # Exploration rate min
epsilon_decay = 0.999     #@param {type:"number"}     # Exploration rate decay

gamma = 0.99          #@param {type:"number"}     # Agent discount factor

# Use the following set of NN hyperparameters for Naive DQN, DQN and DDQN policies
ba =  32       #@param {type:"number"}               # batch_size

# Use the following set of RL hyperparameters for DQN and DDQN policies
target_update_freq = 100 # @param {type:"number"}    # Target network update frequency

# %% [markdown]
# # Q-Network - Baseline

# %% [markdown]
# ## Define and Compile the Neural Network
#
# A single network $Q_\theta$ (parameterized by $\theta$) is used to approximate $Q(s,a)$.
#
# The target used by Naive DQN is then:
#
# $Y^{NaiveQ}_t = R_{t+1} + \gamma Q_{\theta}(S_{t+1}, a)$
#
# The training of Q-Network does NOT rely on a Replay Buffer.

# %%
# Q-Network Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...
from keras.optimizers import Adam


# Define the Q-network
model = Sequential()

# [WriteCode]
# model.add(...
# 添加网络层
model.add(Dense(64, input_dim=4, activation='relu'))  # 输入层：4个状态特征
model.add(Dense(64, activation='relu'))                # 隐藏层
model.add(Dense(2, activation='linear'))               # 输出层：2个动作的Q值


# Compile the model
# [WriteCode]
# 编译模型
model.compile(loss='mse', optimizer=Adam(learning_rate=lr))


# Print the model summary
# [WriteCode]
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,610 (18.01 KB)
#  Trainable params: 4,610 (18.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Set Up Env and Train the Policy

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []


# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "q_net_baseline"  # TensorBoard log directory
cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)

# For timing training
total_training_time = 0

# 检查模型是否已定义
if 'model' not in globals() or model is None:
    raise ValueError("模型未定义！请先运行模型定义cell。")

# 检查模型是否有层
if len(model.layers) == 0:
    raise ValueError("模型没有层！请先运行模型定义cell并确保添加了层。")

print(f"模型已定义，包含 {len(model.layers)} 层")
# Out:
# TensorBoard log directory: c:\Users\roycl\Desktop\EEC4400\eec4400_logs\q_net_baseline\run_2025_11_06-16_19_53
# 模型已定义，包含 3 层

# %%
for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):
        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            # pass # remove pass and use 2 lines below
            q_values = model.predict(state, verbose=0)
            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # Train model using Q-Learning update:  Q(s, a) = r + gamma * max Q(s', a')
        # [WriteCode]

        # Hints:

        # 1. Compute target Q-values:
        # - If done, Q-target = reward (no future reward)
        # - Otherwise, Q-target = reward + gamma * max(Q(next_state, a))
        if done:
            # If done, Q-target = reward (no future reward)
            target_q = reward
        else:
            # Otherwise, Q-target = reward + gamma * max(Q(next_state, a))
            next_q_values = model.predict(next_state, verbose=0)[0]
            target_q = reward + gamma * np.max(next_q_values)
        

        # 2. Predict current Q-values for state
        # Update only the Q-value for the taken action
        q_values = model.predict(state, verbose=0)[0]
        q_values[action] = target_q

        # 3. Fit the model:
        # - Inputs: state
        # - Targets: updated Q-values (with action Q-value replaced by computed target)
        # 移除 TensorBoard 回调以提高速度，只在每个 episode 结束时记录一次
        model.fit(state, q_values.reshape(1, -1), epochs=epoch, verbose=0)


        # Update exploration rate
        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

        state = next_state
        total_reward += reward

        if done:
            break

    # record end time and log the training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]
    # 暂时跳过评估以提高速度，只记录训练奖励
    eval_reward_mean, eval_reward_var = evaluation(model, max_timesteps=500)

    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}"
       f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
       f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
    eval_reward_mean_lst.append(eval_reward_mean)
    eval_reward_var_lst.append(eval_reward_var)
    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
    if eval_reward_mean > 500: # [Modify this threshold as needed]
        print(f"Early stopping triggered at Episode {ep + 1}.")
        break 

# evaluate average training time per episode
print(f"Training time: {total_training_time/(ep + 1):.4f} seconds per episode")

env.close()
# Out:
# Episode 1/250 | Ep. Total Reward: 16.0 | Epsilon : 0.984 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 2/250 | Ep. Total Reward: 13.0 | Epsilon : 0.971 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 3/250 | Ep. Total Reward: 15.0 | Epsilon : 0.957 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 4/250 | Ep. Total Reward: 20.0 | Epsilon : 0.938 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 5/250 | Ep. Total Reward: 18.0 | Epsilon : 0.921 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 6/250 | Ep. Total Reward: 16.0 | Epsilon : 0.907 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 1.04
# Episode 7/250 | Ep. Total Reward: 10.0 | Epsilon : 0.898 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 8/250 | Ep. Total Reward: 20.0 | Epsilon : 0.880 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 9/250 | Ep. Total Reward: 14.0 | Epsilon : 0.868 | Eval Rwd Mean: 8.40 | Eval Rwd Var: 0.24
# Episode 10/250 | Ep. Total Reward: 14.0 | Epsilon : 0.855 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 11/250 | Ep. Total Reward: 24.0 | Epsilon : 0.835 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 12/250 | Ep. Total Reward: 16.0 | Epsilon : 0.822 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 13/250 | Ep. Total Reward: 17.0 | Epsilon : 0.808 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 14/250 | Ep. Total Reward: 18.0 | Epsilon : 0.794 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 15/250 | Ep. Total Reward: 10.0 | Epsilon : 0.786 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 16/250 | Ep. Total Reward: 13.0 | Epsilon : 0.776 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 17/250 | Ep. Total Reward: 10.0 | Epsilon : 0.768 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 18/250 | Ep. Total Reward: 19.0 | Epsilon : 0.753 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 19/250 | Ep. Total Reward: 16.0 | Epsilon : 0.741 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 20/250 | Ep. Total Reward: 8.0 | Epsilon : 0.736 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 21/250 | Ep. Total Reward: 33.0 | Epsilon : 0.712 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 22/250 | Ep. Total Reward: 19.0 | Epsilon : 0.698 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 23/250 | Ep. Total Reward: 17.0 | Epsilon : 0.686 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 24/250 | Ep. Total Reward: 14.0 | Epsilon : 0.677 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 25/250 | Ep. Total Reward: 14.0 | Epsilon : 0.668 | Eval Rwd Mean: 8.40 | Eval Rwd Var: 0.24
# Episode 26/250 | Ep. Total Reward: 9.0 | Epsilon : 0.662 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 27/250 | Ep. Total Reward: 16.0 | Epsilon : 0.651 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 28/250 | Ep. Total Reward: 15.0 | Epsilon : 0.641 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 29/250 | Ep. Total Reward: 16.0 | Epsilon : 0.631 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 30/250 | Ep. Total Reward: 12.0 | Epsilon : 0.624 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 31/250 | Ep. Total Reward: 13.0 | Epsilon : 0.616 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.80
# Episode 32/250 | Ep. Total Reward: 28.0 | Epsilon : 0.599 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 33/250 | Ep. Total Reward: 19.0 | Epsilon : 0.587 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 34/250 | Ep. Total Reward: 38.0 | Epsilon : 0.565 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 35/250 | Ep. Total Reward: 15.0 | Epsilon : 0.557 | Eval Rwd Mean: 8.60 | Eval Rwd Var: 0.24
# Episode 36/250 | Ep. Total Reward: 12.0 | Epsilon : 0.550 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 37/250 | Ep. Total Reward: 10.0 | Epsilon : 0.545 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 38/250 | Ep. Total Reward: 11.0 | Epsilon : 0.539 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 39/250 | Ep. Total Reward: 10.0 | Epsilon : 0.533 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 40/250 | Ep. Total Reward: 10.0 | Epsilon : 0.528 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 41/250 | Ep. Total Reward: 13.0 | Epsilon : 0.521 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 42/250 | Ep. Total Reward: 9.0 | Epsilon : 0.517 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 43/250 | Ep. Total Reward: 13.0 | Epsilon : 0.510 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.00
# Episode 44/250 | Ep. Total Reward: 18.0 | Epsilon : 0.501 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 45/250 | Ep. Total Reward: 14.0 | Epsilon : 0.494 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 46/250 | Ep. Total Reward: 12.0 | Epsilon : 0.488 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 47/250 | Ep. Total Reward: 10.0 | Epsilon : 0.483 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 1.04
# Episode 48/250 | Ep. Total Reward: 11.0 | Epsilon : 0.478 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 49/250 | Ep. Total Reward: 10.0 | Epsilon : 0.473 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 50/250 | Ep. Total Reward: 13.0 | Epsilon : 0.467 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.96
# Episode 51/250 | Ep. Total Reward: 16.0 | Epsilon : 0.460 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 52/250 | Ep. Total Reward: 9.0 | Epsilon : 0.455 | Eval Rwd Mean: 10.40 | Eval Rwd Var: 0.24
# Episode 53/250 | Ep. Total Reward: 14.0 | Epsilon : 0.449 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 54/250 | Ep. Total Reward: 14.0 | Epsilon : 0.443 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 55/250 | Ep. Total Reward: 10.0 | Epsilon : 0.438 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 56/250 | Ep. Total Reward: 11.0 | Epsilon : 0.434 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 57/250 | Ep. Total Reward: 12.0 | Epsilon : 0.429 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 58/250 | Ep. Total Reward: 17.0 | Epsilon : 0.421 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 59/250 | Ep. Total Reward: 18.0 | Epsilon : 0.414 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 60/250 | Ep. Total Reward: 8.0 | Epsilon : 0.410 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 61/250 | Ep. Total Reward: 14.0 | Epsilon : 0.405 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 62/250 | Ep. Total Reward: 11.0 | Epsilon : 0.400 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 63/250 | Ep. Total Reward: 10.0 | Epsilon : 0.396 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 64/250 | Ep. Total Reward: 8.0 | Epsilon : 0.393 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 65/250 | Ep. Total Reward: 12.0 | Epsilon : 0.388 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 66/250 | Ep. Total Reward: 9.0 | Epsilon : 0.385 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 67/250 | Ep. Total Reward: 10.0 | Epsilon : 0.381 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 68/250 | Ep. Total Reward: 17.0 | Epsilon : 0.375 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 69/250 | Ep. Total Reward: 16.0 | Epsilon : 0.369 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 70/250 | Ep. Total Reward: 13.0 | Epsilon : 0.364 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.16
# Episode 71/250 | Ep. Total Reward: 8.0 | Epsilon : 0.361 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 72/250 | Ep. Total Reward: 15.0 | Epsilon : 0.356 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 73/250 | Ep. Total Reward: 9.0 | Epsilon : 0.353 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 74/250 | Ep. Total Reward: 11.0 | Epsilon : 0.349 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 75/250 | Ep. Total Reward: 10.0 | Epsilon : 0.345 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.80
# Episode 76/250 | Ep. Total Reward: 12.0 | Epsilon : 0.341 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 77/250 | Ep. Total Reward: 8.0 | Epsilon : 0.338 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 78/250 | Ep. Total Reward: 11.0 | Epsilon : 0.335 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 79/250 | Ep. Total Reward: 10.0 | Epsilon : 0.331 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 80/250 | Ep. Total Reward: 11.0 | Epsilon : 0.328 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 81/250 | Ep. Total Reward: 13.0 | Epsilon : 0.323 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 82/250 | Ep. Total Reward: 11.0 | Epsilon : 0.320 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 83/250 | Ep. Total Reward: 9.0 | Epsilon : 0.317 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 84/250 | Ep. Total Reward: 11.0 | Epsilon : 0.314 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 85/250 | Ep. Total Reward: 15.0 | Epsilon : 0.309 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.96
# Episode 86/250 | Ep. Total Reward: 18.0 | Epsilon : 0.303 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 87/250 | Ep. Total Reward: 12.0 | Epsilon : 0.300 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 88/250 | Ep. Total Reward: 12.0 | Epsilon : 0.296 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 89/250 | Ep. Total Reward: 9.0 | Epsilon : 0.294 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 1.20
# Episode 90/250 | Ep. Total Reward: 12.0 | Epsilon : 0.290 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 91/250 | Ep. Total Reward: 11.0 | Epsilon : 0.287 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 92/250 | Ep. Total Reward: 14.0 | Epsilon : 0.283 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 93/250 | Ep. Total Reward: 8.0 | Epsilon : 0.281 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 94/250 | Ep. Total Reward: 11.0 | Epsilon : 0.278 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 95/250 | Ep. Total Reward: 17.0 | Epsilon : 0.273 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 96/250 | Ep. Total Reward: 12.0 | Epsilon : 0.270 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 97/250 | Ep. Total Reward: 10.0 | Epsilon : 0.267 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 98/250 | Ep. Total Reward: 8.0 | Epsilon : 0.265 | Eval Rwd Mean: 10.40 | Eval Rwd Var: 0.64
# Episode 99/250 | Ep. Total Reward: 10.0 | Epsilon : 0.262 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 100/250 | Ep. Total Reward: 9.0 | Epsilon : 0.260 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 101/250 | Ep. Total Reward: 9.0 | Epsilon : 0.258 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 102/250 | Ep. Total Reward: 9.0 | Epsilon : 0.255 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 103/250 | Ep. Total Reward: 12.0 | Epsilon : 0.252 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 104/250 | Ep. Total Reward: 9.0 | Epsilon : 0.250 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 105/250 | Ep. Total Reward: 15.0 | Epsilon : 0.246 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 106/250 | Ep. Total Reward: 10.0 | Epsilon : 0.244 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 107/250 | Ep. Total Reward: 9.0 | Epsilon : 0.242 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.96
# Episode 108/250 | Ep. Total Reward: 9.0 | Epsilon : 0.239 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 109/250 | Ep. Total Reward: 11.0 | Epsilon : 0.237 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 110/250 | Ep. Total Reward: 11.0 | Epsilon : 0.234 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 111/250 | Ep. Total Reward: 9.0 | Epsilon : 0.232 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 112/250 | Ep. Total Reward: 10.0 | Epsilon : 0.230 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 113/250 | Ep. Total Reward: 9.0 | Epsilon : 0.228 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 114/250 | Ep. Total Reward: 12.0 | Epsilon : 0.225 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 115/250 | Ep. Total Reward: 12.0 | Epsilon : 0.222 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.16
# Episode 116/250 | Ep. Total Reward: 13.0 | Epsilon : 0.219 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 117/250 | Ep. Total Reward: 11.0 | Epsilon : 0.217 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 118/250 | Ep. Total Reward: 8.0 | Epsilon : 0.215 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 1.36
# Episode 119/250 | Ep. Total Reward: 12.0 | Epsilon : 0.213 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 120/250 | Ep. Total Reward: 9.0 | Epsilon : 0.211 | Eval Rwd Mean: 8.60 | Eval Rwd Var: 0.24
# Episode 121/250 | Ep. Total Reward: 10.0 | Epsilon : 0.209 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.16
# Episode 122/250 | Ep. Total Reward: 10.0 | Epsilon : 0.207 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 1.20
# Episode 123/250 | Ep. Total Reward: 9.0 | Epsilon : 0.205 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 1.20
# Episode 124/250 | Ep. Total Reward: 15.0 | Epsilon : 0.202 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 125/250 | Ep. Total Reward: 9.0 | Epsilon : 0.200 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 126/250 | Ep. Total Reward: 8.0 | Epsilon : 0.198 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 127/250 | Ep. Total Reward: 9.0 | Epsilon : 0.197 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 128/250 | Ep. Total Reward: 11.0 | Epsilon : 0.194 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 129/250 | Ep. Total Reward: 12.0 | Epsilon : 0.192 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 130/250 | Ep. Total Reward: 9.0 | Epsilon : 0.190 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.44
# Episode 131/250 | Ep. Total Reward: 10.0 | Epsilon : 0.188 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.80
# Episode 132/250 | Ep. Total Reward: 13.0 | Epsilon : 0.186 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.96
# Episode 133/250 | Ep. Total Reward: 10.0 | Epsilon : 0.184 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 134/250 | Ep. Total Reward: 9.0 | Epsilon : 0.183 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 135/250 | Ep. Total Reward: 11.0 | Epsilon : 0.181 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 136/250 | Ep. Total Reward: 10.0 | Epsilon : 0.179 | Eval Rwd Mean: 8.40 | Eval Rwd Var: 0.64
# Episode 137/250 | Ep. Total Reward: 10.0 | Epsilon : 0.177 | Eval Rwd Mean: 10.40 | Eval Rwd Var: 0.24
# Episode 138/250 | Ep. Total Reward: 9.0 | Epsilon : 0.175 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 139/250 | Ep. Total Reward: 13.0 | Epsilon : 0.173 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 1.36
# Episode 140/250 | Ep. Total Reward: 12.0 | Epsilon : 0.171 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.44
# Episode 141/250 | Ep. Total Reward: 9.0 | Epsilon : 0.170 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 142/250 | Ep. Total Reward: 11.0 | Epsilon : 0.168 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 143/250 | Ep. Total Reward: 13.0 | Epsilon : 0.165 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 144/250 | Ep. Total Reward: 9.0 | Epsilon : 0.164 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 145/250 | Ep. Total Reward: 11.0 | Epsilon : 0.162 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 146/250 | Ep. Total Reward: 12.0 | Epsilon : 0.160 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 147/250 | Ep. Total Reward: 8.0 | Epsilon : 0.159 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 148/250 | Ep. Total Reward: 9.0 | Epsilon : 0.158 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 149/250 | Ep. Total Reward: 10.0 | Epsilon : 0.156 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.96
# Episode 150/250 | Ep. Total Reward: 9.0 | Epsilon : 0.155 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 151/250 | Ep. Total Reward: 12.0 | Epsilon : 0.153 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 1.36
# Episode 152/250 | Ep. Total Reward: 9.0 | Epsilon : 0.151 | Eval Rwd Mean: 10.40 | Eval Rwd Var: 0.64
# Episode 153/250 | Ep. Total Reward: 10.0 | Epsilon : 0.150 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.56
# Episode 154/250 | Ep. Total Reward: 9.0 | Epsilon : 0.149 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.96
# Episode 155/250 | Ep. Total Reward: 10.0 | Epsilon : 0.147 | Eval Rwd Mean: 8.40 | Eval Rwd Var: 0.24
# Episode 156/250 | Ep. Total Reward: 11.0 | Epsilon : 0.145 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 157/250 | Ep. Total Reward: 13.0 | Epsilon : 0.144 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 158/250 | Ep. Total Reward: 14.0 | Epsilon : 0.142 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 159/250 | Ep. Total Reward: 9.0 | Epsilon : 0.140 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 1.04
# Episode 160/250 | Ep. Total Reward: 10.0 | Epsilon : 0.139 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 161/250 | Ep. Total Reward: 8.0 | Epsilon : 0.138 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 1.20
# Episode 162/250 | Ep. Total Reward: 9.0 | Epsilon : 0.137 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.96
# Episode 163/250 | Ep. Total Reward: 11.0 | Epsilon : 0.135 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.16
# Episode 164/250 | Ep. Total Reward: 11.0 | Epsilon : 0.134 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 1.04
# Episode 165/250 | Ep. Total Reward: 10.0 | Epsilon : 0.132 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 0.24
# Episode 166/250 | Ep. Total Reward: 9.0 | Epsilon : 0.131 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 167/250 | Ep. Total Reward: 10.0 | Epsilon : 0.130 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.56
# Episode 168/250 | Ep. Total Reward: 9.0 | Epsilon : 0.129 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 169/250 | Ep. Total Reward: 10.0 | Epsilon : 0.127 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 1.04
# Episode 170/250 | Ep. Total Reward: 14.0 | Epsilon : 0.126 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.56
# Episode 171/250 | Ep. Total Reward: 10.0 | Epsilon : 0.124 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 172/250 | Ep. Total Reward: 10.0 | Epsilon : 0.123 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 1.04
# Episode 173/250 | Ep. Total Reward: 11.0 | Epsilon : 0.122 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 174/250 | Ep. Total Reward: 9.0 | Epsilon : 0.121 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 175/250 | Ep. Total Reward: 10.0 | Epsilon : 0.119 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 176/250 | Ep. Total Reward: 10.0 | Epsilon : 0.118 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 177/250 | Ep. Total Reward: 11.0 | Epsilon : 0.117 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 178/250 | Ep. Total Reward: 9.0 | Epsilon : 0.116 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.80
# Episode 179/250 | Ep. Total Reward: 10.0 | Epsilon : 0.115 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 180/250 | Ep. Total Reward: 8.0 | Epsilon : 0.114 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 181/250 | Ep. Total Reward: 13.0 | Epsilon : 0.112 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 182/250 | Ep. Total Reward: 11.0 | Epsilon : 0.111 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 183/250 | Ep. Total Reward: 11.0 | Epsilon : 0.110 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 184/250 | Ep. Total Reward: 8.0 | Epsilon : 0.109 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 185/250 | Ep. Total Reward: 9.0 | Epsilon : 0.108 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.96
# Episode 186/250 | Ep. Total Reward: 8.0 | Epsilon : 0.107 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 187/250 | Ep. Total Reward: 10.0 | Epsilon : 0.106 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.80
# Episode 188/250 | Ep. Total Reward: 8.0 | Epsilon : 0.105 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 189/250 | Ep. Total Reward: 10.0 | Epsilon : 0.104 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.96
# Episode 190/250 | Ep. Total Reward: 10.0 | Epsilon : 0.103 | Eval Rwd Mean: 10.80 | Eval Rwd Var: 0.56
# Episode 191/250 | Ep. Total Reward: 11.0 | Epsilon : 0.102 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 192/250 | Ep. Total Reward: 9.0 | Epsilon : 0.101 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.96
# Episode 193/250 | Ep. Total Reward: 12.0 | Epsilon : 0.100 | Eval Rwd Mean: 10.40 | Eval Rwd Var: 0.64
# Episode 194/250 | Ep. Total Reward: 11.0 | Epsilon : 0.099 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.44
# Episode 195/250 | Ep. Total Reward: 11.0 | Epsilon : 0.098 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 0.64
# Episode 196/250 | Ep. Total Reward: 11.0 | Epsilon : 0.097 | Eval Rwd Mean: 11.40 | Eval Rwd Var: 0.24
# Episode 197/250 | Ep. Total Reward: 11.0 | Epsilon : 0.096 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 198/250 | Ep. Total Reward: 12.0 | Epsilon : 0.094 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.04
# Episode 199/250 | Ep. Total Reward: 10.0 | Epsilon : 0.094 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 0.24
# Episode 200/250 | Ep. Total Reward: 10.0 | Epsilon : 0.093 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 2.00
# Episode 201/250 | Ep. Total Reward: 11.0 | Epsilon : 0.092 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 0.40
# Episode 202/250 | Ep. Total Reward: 14.0 | Epsilon : 0.090 | Eval Rwd Mean: 11.00 | Eval Rwd Var: 0.80
# Episode 203/250 | Ep. Total Reward: 11.0 | Epsilon : 0.089 | Eval Rwd Mean: 10.40 | Eval Rwd Var: 0.24
# Episode 204/250 | Ep. Total Reward: 9.0 | Epsilon : 0.089 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 1.60
# Episode 205/250 | Ep. Total Reward: 9.0 | Epsilon : 0.088 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 1.04
# Episode 206/250 | Ep. Total Reward: 9.0 | Epsilon : 0.087 | Eval Rwd Mean: 11.00 | Eval Rwd Var: 0.40
# Episode 207/250 | Ep. Total Reward: 11.0 | Epsilon : 0.086 | Eval Rwd Mean: 11.40 | Eval Rwd Var: 1.04
# Episode 208/250 | Ep. Total Reward: 10.0 | Epsilon : 0.085 | Eval Rwd Mean: 11.00 | Eval Rwd Var: 1.60
# Episode 209/250 | Ep. Total Reward: 12.0 | Epsilon : 0.084 | Eval Rwd Mean: 11.00 | Eval Rwd Var: 1.60
# Episode 210/250 | Ep. Total Reward: 11.0 | Epsilon : 0.083 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 0.64
# Episode 211/250 | Ep. Total Reward: 11.0 | Epsilon : 0.082 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 1.84
# Episode 212/250 | Ep. Total Reward: 10.0 | Epsilon : 0.081 | Eval Rwd Mean: 12.00 | Eval Rwd Var: 1.60
# Episode 213/250 | Ep. Total Reward: 10.0 | Epsilon : 0.081 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 1.44
# Episode 214/250 | Ep. Total Reward: 12.0 | Epsilon : 0.080 | Eval Rwd Mean: 12.00 | Eval Rwd Var: 1.60
# Episode 215/250 | Ep. Total Reward: 12.0 | Epsilon : 0.079 | Eval Rwd Mean: 10.60 | Eval Rwd Var: 1.44
# Episode 216/250 | Ep. Total Reward: 12.0 | Epsilon : 0.078 | Eval Rwd Mean: 11.20 | Eval Rwd Var: 1.36
# Episode 217/250 | Ep. Total Reward: 13.0 | Epsilon : 0.077 | Eval Rwd Mean: 12.60 | Eval Rwd Var: 0.24
# Episode 218/250 | Ep. Total Reward: 10.0 | Epsilon : 0.076 | Eval Rwd Mean: 13.00 | Eval Rwd Var: 4.80
# Episode 219/250 | Ep. Total Reward: 14.0 | Epsilon : 0.075 | Eval Rwd Mean: 12.60 | Eval Rwd Var: 4.24
# Episode 220/250 | Ep. Total Reward: 14.0 | Epsilon : 0.074 | Eval Rwd Mean: 12.40 | Eval Rwd Var: 0.64
# Episode 221/250 | Ep. Total Reward: 11.0 | Epsilon : 0.073 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 6.16
# Episode 222/250 | Ep. Total Reward: 16.0 | Epsilon : 0.072 | Eval Rwd Mean: 13.80 | Eval Rwd Var: 3.76
# Episode 223/250 | Ep. Total Reward: 10.0 | Epsilon : 0.071 | Eval Rwd Mean: 13.00 | Eval Rwd Var: 2.00
# Episode 224/250 | Ep. Total Reward: 15.0 | Epsilon : 0.070 | Eval Rwd Mean: 11.60 | Eval Rwd Var: 1.04
# Episode 225/250 | Ep. Total Reward: 13.0 | Epsilon : 0.069 | Eval Rwd Mean: 12.80 | Eval Rwd Var: 0.56
# Episode 226/250 | Ep. Total Reward: 12.0 | Epsilon : 0.068 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 5.76
# Episode 227/250 | Ep. Total Reward: 15.0 | Epsilon : 0.067 | Eval Rwd Mean: 12.80 | Eval Rwd Var: 2.96
# Episode 228/250 | Ep. Total Reward: 14.0 | Epsilon : 0.067 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 1.36
# Episode 229/250 | Ep. Total Reward: 13.0 | Epsilon : 0.066 | Eval Rwd Mean: 12.20 | Eval Rwd Var: 0.56
# Episode 230/250 | Ep. Total Reward: 11.0 | Epsilon : 0.065 | Eval Rwd Mean: 13.20 | Eval Rwd Var: 0.56
# Episode 231/250 | Ep. Total Reward: 17.0 | Epsilon : 0.064 | Eval Rwd Mean: 14.80 | Eval Rwd Var: 2.56
# Episode 232/250 | Ep. Total Reward: 15.0 | Epsilon : 0.063 | Eval Rwd Mean: 12.80 | Eval Rwd Var: 1.76
# Episode 233/250 | Ep. Total Reward: 16.0 | Epsilon : 0.062 | Eval Rwd Mean: 13.60 | Eval Rwd Var: 0.64
# Episode 234/250 | Ep. Total Reward: 16.0 | Epsilon : 0.061 | Eval Rwd Mean: 16.60 | Eval Rwd Var: 5.44
# Episode 235/250 | Ep. Total Reward: 21.0 | Epsilon : 0.060 | Eval Rwd Mean: 19.60 | Eval Rwd Var: 5.84
# Episode 236/250 | Ep. Total Reward: 16.0 | Epsilon : 0.059 | Eval Rwd Mean: 17.20 | Eval Rwd Var: 4.16
# Episode 237/250 | Ep. Total Reward: 22.0 | Epsilon : 0.057 | Eval Rwd Mean: 20.60 | Eval Rwd Var: 9.84
# Episode 238/250 | Ep. Total Reward: 22.0 | Epsilon : 0.056 | Eval Rwd Mean: 21.40 | Eval Rwd Var: 12.24
# Episode 239/250 | Ep. Total Reward: 21.0 | Epsilon : 0.055 | Eval Rwd Mean: 20.00 | Eval Rwd Var: 14.80
# Episode 240/250 | Ep. Total Reward: 19.0 | Epsilon : 0.054 | Eval Rwd Mean: 23.00 | Eval Rwd Var: 7.20
# Episode 241/250 | Ep. Total Reward: 21.0 | Epsilon : 0.053 | Eval Rwd Mean: 20.80 | Eval Rwd Var: 5.36
# Episode 242/250 | Ep. Total Reward: 21.0 | Epsilon : 0.052 | Eval Rwd Mean: 26.00 | Eval Rwd Var: 26.80
# Episode 243/250 | Ep. Total Reward: 21.0 | Epsilon : 0.051 | Eval Rwd Mean: 24.20 | Eval Rwd Var: 13.36
# Episode 244/250 | Ep. Total Reward: 21.0 | Epsilon : 0.050 | Eval Rwd Mean: 26.00 | Eval Rwd Var: 28.80
# Episode 245/250 | Ep. Total Reward: 32.0 | Epsilon : 0.048 | Eval Rwd Mean: 26.20 | Eval Rwd Var: 10.16
# Episode 246/250 | Ep. Total Reward: 30.0 | Epsilon : 0.047 | Eval Rwd Mean: 30.80 | Eval Rwd Var: 40.16
# Episode 247/250 | Ep. Total Reward: 33.0 | Epsilon : 0.045 | Eval Rwd Mean: 35.80 | Eval Rwd Var: 92.56
# Episode 248/250 | Ep. Total Reward: 73.0 | Epsilon : 0.042 | Eval Rwd Mean: 9.00 | Eval Rwd Var: 0.40
# Episode 249/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 250/250 | Ep. Total Reward: 14.0 | Epsilon : 0.041 | Eval Rwd Mean: 16.60 | Eval Rwd Var: 4.24
# Training time: 5.0603 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]

# plot_smoothed_training_rwd(...
print("--- Plotting Results for Q-Network Baseline Model ---")
plot_smoothed_training_rwd(train_reward_lst, window_size=20)

# plot_eval_rwd_mean(...
plot_eval_rwd_mean(eval_reward_mean_lst)

# plot_eval_rwd_var(...
plot_eval_rwd_var(eval_reward_var_lst)
# Out:
# --- Plotting Results for Q-Network Baseline Model ---

# %% [markdown]
# # Q-Network - Alternative

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative Naive Q-Network policies

# %%
# [Write Code]

# %% [markdown]
# # Experience Replay Framework
#
# By now, you may have noticed that in a standard RL setup, the agent **only learns from its most recent experience** at each step. This makes training unstable and inefficient. Additionally, consecutive experiences are often highly correlated, which can lead to poor generalization.
#
# To address this, we will adopt the **Experience Replay Framework**, where past interactions are stored in a **Replay Buffer** and **a randomly sampled batch** is used to update the decision-making policy. This helps to:
#
# - **Break correlation** between consecutive experiences, stabilizing learning.
# - **Improve data efficiency** by reusing past experiences multiple times.
# - **Smooth training updates**, preventing abrupt policy changes.
#
# The figure below illustrates this process:
# ![dqn-agent.png](attachment:a59a0ba3-95f7-4a60-baa3-bbb9c924e972.png)
#
# - The Agent interacts with the Environment, taking actions based on its learned policy.
# - The Replay Buffer stores past experiences `(state, action, reward, next state, done)`.
# - Instead of updating after every step, the agent samples from the buffer and learns from past interactions.
#
# This framework is used in naive DQN, DQN and DDQN to stabilize Q-learning.

# %% [markdown]
# ## Implement Replay Buffer and Functions

# %%
# Store (state, action, reward, next_state, done)
def store_experience(replay_buffer, state, action, reward, next_stat, done):
        replay_buffer.append((state, action, reward, next_state, done))

# Sample (state, action, reward, next_state, done) mini-batch for training
def sample_experience(replay_buffer, batch_size):

    # Ensure we have enough samples
    assert len(replay_buffer) >= batch_size, (
        f"Not enough samples in buffer to sample {batch_size} items.")

    # Sample a mini-batch
    minibatch = random.sample(replay_buffer, batch_size)

    states, actions, rewards, next_states, dones = zip(*minibatch)  #将数据按类别分开

    states = np.array(states, dtype=np.float32).squeeze()   #.squeeze() 用于移除数组中维度为 1 的轴
    next_states = np.array(next_states, dtype=np.float32).squeeze()
    actions = np.array(actions, dtype=np.int32)
    rewards = np.array(rewards, dtype=np.float32)
    dones = np.array(dones, dtype=np.float32)

    return states, actions, rewards, next_states, dones

# [Hint] You may find the following statements useful
"""
# Define replay buffer
replay_buffer = deque(maxlen=10000)

# Store experience tuple into replay_buffer
store_experience(replay_buffer, state, action, reward, next_state, done)

# Sample mini-batch of size ba from replay_buffer
states, actions, rewards, next_states, dones = sample_experience(replay_buffer, ba)
"""
# Out:
# '\n# Define replay buffer\nreplay_buffer = deque(maxlen=10000)\n\n# Store experience tuple into replay_buffer\nstore_experience(replay_buffer, state, action, reward, next_state, done)\n\n# Sample mini-batch of size ba from replay_buffer\nstates, actions, rewards, next_states, dones = sample_experience(replay_buffer, ba)\n'

# %% [markdown]
# # Naive DQN - Baseline
#
# In this section, you will complete the Naive DQN alorithm by implementing the missing components marked as `[WriteCode]`.

# %% [markdown]
# ## Define and Compile the Neural Network
#
# A single network $Q_\theta$ (parameterized by $\theta$) is used to approximate $Q(s,a)$.
#
# The target used by Naive DQN is then:
#
# $Y^{NaiveQ}_t = R_{t+1} + \gamma Q_{\theta}(S_{t+1}, a)$

# %%
# Naive DQN Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...

# Define the Q-network
model = Sequential()

# [WriteCode]
# model.add(...

# Compile the model
# [WriteCode]

# Print the model summary
# [WriteCode]

# %% [markdown]
# ## Set Up Env and Train the Policy

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []

# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "naive_dqn_baseline"  # TensorBoard log directory
cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)

# For timing training
total_training_time = 0

# Define replay buffer
# [WriteCode]
# replay_buffer = ...

for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):
        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            pass # remove pass and use 2 lines below
#            q_values = model.predict(state, verbose=0)
#            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # store experience into replay buffer
        # [WriteCode]

        state = next_state
        total_reward += reward

        if done:
            break


#        if len(replay_buffer) >= ba:
            # Update policy with mini-batches if replay buffer contains enough samples
            # Update policy using Q-Learning update:  Q(s, a) = r + gamma * max Q(s', a')
            # [WriteCode]

            # Hints:

            # 1. Compute target Q-values:
            # - If done, Q-target = reward (no future reward)
            # - Otherwise, Q-target = reward + gamma * max(Q(next_state, a))

            # 2. Predict current Q-values for state
            # Update only the Q-value for the taken action

            # 3. Fit the model:
            # - Inputs: state
            # - Targets: updated Q-values (with action Q-value replaced by computed target)

            # Update exploration rate
            if epsilon > epsilon_min:
                epsilon *= epsilon_decay

    # record end time and log training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]


    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}")
#        f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
#        f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
#    eval_reward_mean_lst.append(eval_reward_mean)
#    eval_reward_var_lst.append(eval_reward_var)
#    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
#    if eval_reward_mean > 500: # [Modify this threshold as needed]
#        print(f"Early stopping triggered at Episode {ep + 1}.")
#        break

# evaluate average training time per episode
print(f"Training time: {total_training_time/episode:.4f} seconds per episode")

env.close()
# Out:
# TensorBoard log directory: c:\Users\roycl\Desktop\EEC4400\eec4400_logs\naive_dqn_baseline\run_2025_11_06-17_04_17
# Episode 1/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 2/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 3/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 4/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 5/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 6/250 | Ep. Total Reward: 13.0 | Epsilon : 0.041
# Episode 7/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 8/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 9/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 10/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 11/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 12/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 13/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 14/250 | Ep. Total Reward: 18.0 | Epsilon : 0.041
# Episode 15/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 16/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 17/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 18/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 19/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 20/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 21/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 22/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 23/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 24/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 25/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 26/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 27/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 28/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 29/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 30/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 31/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 32/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 33/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 34/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 35/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 36/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 37/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 38/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 39/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 40/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 41/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 42/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 43/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 44/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 45/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 46/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 47/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 48/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 49/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 50/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 51/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 52/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 53/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 54/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 55/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 56/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 57/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 58/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 59/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 60/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 61/250 | Ep. Total Reward: 17.0 | Epsilon : 0.041
# Episode 62/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 63/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 64/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 65/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 66/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 67/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 68/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 69/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 70/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 71/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 72/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 73/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 74/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 75/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 76/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 77/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 78/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 79/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 80/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 81/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 82/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 83/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 84/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 85/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 86/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 87/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 88/250 | Ep. Total Reward: 17.0 | Epsilon : 0.041
# Episode 89/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 90/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 91/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 92/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 93/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 94/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 95/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 96/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 97/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 98/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 99/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 100/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 101/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 102/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 103/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 104/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 105/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 106/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 107/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 108/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 109/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 110/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 111/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 112/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 113/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 114/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 115/250 | Ep. Total Reward: 17.0 | Epsilon : 0.041
# Episode 116/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 117/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 118/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 119/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 120/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 121/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 122/250 | Ep. Total Reward: 19.0 | Epsilon : 0.041
# Episode 123/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 124/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 125/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 126/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 127/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 128/250 | Ep. Total Reward: 17.0 | Epsilon : 0.041
# Episode 129/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 130/250 | Ep. Total Reward: 16.0 | Epsilon : 0.041
# Episode 131/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 132/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 133/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 134/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 135/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 136/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 137/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 138/250 | Ep. Total Reward: 13.0 | Epsilon : 0.041
# Episode 139/250 | Ep. Total Reward: 16.0 | Epsilon : 0.041
# Episode 140/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 141/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 142/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 143/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 144/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 145/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 146/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 147/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 148/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 149/250 | Ep. Total Reward: 21.0 | Epsilon : 0.041
# Episode 150/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 151/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 152/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 153/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 154/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 155/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 156/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 157/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 158/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 159/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 160/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 161/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 162/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 163/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 164/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 165/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 166/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 167/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 168/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 169/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 170/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 171/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 172/250 | Ep. Total Reward: 22.0 | Epsilon : 0.041
# Episode 173/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 174/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 175/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 176/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 177/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 178/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 179/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 180/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 181/250 | Ep. Total Reward: 21.0 | Epsilon : 0.041
# Episode 182/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 183/250 | Ep. Total Reward: 13.0 | Epsilon : 0.041
# Episode 184/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 185/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 186/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 187/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 188/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 189/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 190/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 191/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 192/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 193/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 194/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 195/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 196/250 | Ep. Total Reward: 17.0 | Epsilon : 0.041
# Episode 197/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 198/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 199/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 200/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 201/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 202/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 203/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 204/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 205/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 206/250 | Ep. Total Reward: 15.0 | Epsilon : 0.041
# Episode 207/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 208/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 209/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 210/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 211/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 212/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 213/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 214/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 215/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 216/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 217/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 218/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 219/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 220/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 221/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 222/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 223/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 224/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 225/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 226/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 227/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 228/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 229/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 230/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 231/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 232/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 233/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 234/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 235/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 236/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 237/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 238/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 239/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 240/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 241/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 242/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 243/250 | Ep. Total Reward: 13.0 | Epsilon : 0.041
# Episode 244/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 245/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 246/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 247/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 248/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 249/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 250/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Training time: 0.0003 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]

# plot_smoothed_training_rwd(...

# plot_eval_rwd_mean(...

# plot_eval_rwd_var(...

# %% [markdown]
# # Naive DQN - Alternative
# You may insert extra cells in the notebook to perform tuning experiments and log results effectively. Use TensorBoard, plots, or tables to visualize the impact of different hyperparameter choices.

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative Naive DQN Policies

# %%
# [Write Code]

# %% [markdown]
# # DQN
#
# In this section, you will complete the DQN algorithm by implementing the missing components marked as `[WriteCode]`.

# %% [markdown]
# ## Define and Compile the Neural Networks

# %% [markdown]
# The standard DQN [https://arxiv.org/abs/1312.5602] approach features a periodically updated target network to stabilize training:
#
# - `target_model`: A periodically updated network that stabilizes training. During training, this network is used to compute $Q(S_{t+1}, a)$ for each possible action $a$. This network is not actively trained, but at regular intervals, its weights are copied from `eval_model`. This prevents rapid fluctuations in target Q-values and improves learning stability.
#
# - `eval_model`: The online learning network that interacts with the environment. During training, this network is used to compute $Q(S_{t}, a)$ for each possible action $a$. It updates its weights by minimizing the difference between predicted and target Q-values, improving the agent's decision-making over time.
#
# The target used by DQN is then:
#
# $Y^{Q}_t = R_{t+1} + \gamma \max_a Q_{target}(S_{t+1}, a)$
#
# In the following section, define `[eval_model]` and `[target_model]` with identical architectures.

# %%
# DQN Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...

# Define the eval (online) network
eval_model = Sequential()

# [WriteCode]
# model.add(...

# Compile the model
# [WriteCode]

# Print the model summary
# [WriteCode]


# Create target_model with the same architecture
target_model = Sequential()

# [WriteCode]
# model.add(...

# Skip compiling as target_model will not be trained with .fit()
# Instead, weights will be copied from the online model
target_model.set_weights(eval_model.get_weights())

# Print the model summary
# [WriteCode]
print(target_model.summary())
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Set Up Env and Train the Policy

# %% [markdown]
# In this section, you will complete the DQN training routine by implementing the missing components marked as `[WriteCode]`.

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []

# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "dqn_baseline"   # TensorBoard log directory
cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)

# Train Counter for weight syncing
train_counter = 0

# For timing training
total_training_time = 0

# Define replay buffer
# replay_buffer = ...

for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):
        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            pass # remove pass and 2 lines below
#            q_values = eval_model.predict(state, verbose=0)
#            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # store experience into replay buffer
        # [WriteCode]

        state = next_state
        total_reward += reward

        if done:
            break

        # if len(replay_buffer) >= ba:
            # train_counter += 1
            # Update policy with mini-batches if replay buffer contains enough samples
            # Update policy using Deep Q-Learning update: Q(s, a) = r + gamma * max Q_target(S', a)
            # [WriteCode]

            # Compute target Q-values:
            # - If done, Q-target = reward (no future reward)
            # - Otherwise, Q-target = reward + gamma * max(Q_target(next_state, a))

            # Predict current Q-values for state using eval_model
            # Predict future Q-values using target_model (NOT eval_model)

            # Update only the Q-value for the taken action

            # Fit the model:
            # - Inputs: state
            # - Targets: updated Q-values (with action Q-value replaced by computed target)


            # Update exploration rate
            if epsilon > epsilon_min:
                epsilon *= epsilon_decay

            # Periodically update the target network
            if train_counter % target_update_freq == 0:
                target_model.set_weights(eval_model.get_weights())

    # record end time and log training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]

    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}")
#        f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
#        f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
#    eval_reward_mean_lst.append(eval_reward_mean)
#    eval_reward_var_lst.append(eval_reward_var)
#    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
#    if eval_reward_mean > 500: # [Modify this threshold as needed]
#        print(f"Early stopping triggered at Episode {ep + 1}.")
#        break

# evaluate average training time per episode
print(f"Training time: {total_training_time/episode:.4f} seconds per episode")

env.close()
# Out:
# TensorBoard log directory: c:\Users\roycl\Desktop\EEC4400\eec4400_logs\dqn_baseline\run_2025_11_06-17_04_18
# Episode 1/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 2/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 3/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 4/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 5/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 6/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 7/250 | Ep. Total Reward: 14.0 | Epsilon : 0.041
# Episode 8/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 9/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 10/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 11/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 12/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 13/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 14/250 | Ep. Total Reward: 22.0 | Epsilon : 0.041
# Episode 15/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 16/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 17/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 18/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 19/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 20/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 21/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 22/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 23/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 24/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 25/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 26/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 27/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 28/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 29/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 30/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 31/250 | Ep. Total Reward: 16.0 | Epsilon : 0.041
# Episode 32/250 | Ep. Total Reward: 18.0 | Epsilon : 0.041
# Episode 33/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 34/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 35/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 36/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 37/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 38/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 39/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 40/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 41/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 42/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 43/250 | Ep. Total Reward: 18.0 | Epsilon : 0.041
# Episode 44/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 45/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 46/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 47/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 48/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 49/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 50/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 51/250 | Ep. Total Reward: 27.0 | Epsilon : 0.041
# Episode 52/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 53/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 54/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 55/250 | Ep. Total Reward: 23.0 | Epsilon : 0.041
# Episode 56/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 57/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 58/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 59/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 60/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 61/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 62/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 63/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 64/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 65/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 66/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 67/250 | Ep. Total Reward: 13.0 | Epsilon : 0.041
# Episode 68/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 69/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 70/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 71/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 72/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 73/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 74/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 75/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 76/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 77/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 78/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 79/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 80/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 81/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 82/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 83/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 84/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 85/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 86/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 87/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 88/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 89/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 90/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 91/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 92/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 93/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 94/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 95/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 96/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 97/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 98/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 99/250 | Ep. Total Reward: 15.0 | Epsilon : 0.041
# Episode 100/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 101/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 102/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 103/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 104/250 | Ep. Total Reward: 19.0 | Epsilon : 0.041
# Episode 105/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 106/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 107/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 108/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 109/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 110/250 | Ep. Total Reward: 18.0 | Epsilon : 0.041
# Episode 111/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 112/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 113/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 114/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 115/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 116/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 117/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 118/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 119/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 120/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 121/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 122/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 123/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 124/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 125/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 126/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 127/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 128/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 129/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 130/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 131/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 132/250 | Ep. Total Reward: 21.0 | Epsilon : 0.041
# Episode 133/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 134/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 135/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 136/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 137/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 138/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 139/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 140/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 141/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 142/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 143/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 144/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 145/250 | Ep. Total Reward: 15.0 | Epsilon : 0.041
# Episode 146/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 147/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 148/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 149/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 150/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 151/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 152/250 | Ep. Total Reward: 26.0 | Epsilon : 0.041
# Episode 153/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 154/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 155/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 156/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 157/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 158/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 159/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 160/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 161/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 162/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 163/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 164/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 165/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 166/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 167/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 168/250 | Ep. Total Reward: 13.0 | Epsilon : 0.041
# Episode 169/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 170/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 171/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 172/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 173/250 | Ep. Total Reward: 18.0 | Epsilon : 0.041
# Episode 174/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 175/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 176/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 177/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 178/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 179/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 180/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 181/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 182/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 183/250 | Ep. Total Reward: 17.0 | Epsilon : 0.041
# Episode 184/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 185/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 186/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 187/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 188/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 189/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 190/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 191/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 192/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 193/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 194/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 195/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 196/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 197/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 198/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 199/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 200/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 201/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 202/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 203/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 204/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 205/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 206/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 207/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 208/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 209/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 210/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 211/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 212/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 213/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 214/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 215/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 216/250 | Ep. Total Reward: 25.0 | Epsilon : 0.041
# Episode 217/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 218/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 219/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 220/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 221/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 222/250 | Ep. Total Reward: 15.0 | Epsilon : 0.041
# Episode 223/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 224/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 225/250 | Ep. Total Reward: 18.0 | Epsilon : 0.041
# Episode 226/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 227/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 228/250 | Ep. Total Reward: 12.0 | Epsilon : 0.041
# Episode 229/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 230/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 231/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 232/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 233/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 234/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 235/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 236/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Episode 237/250 | Ep. Total Reward: 16.0 | Epsilon : 0.041
# Episode 238/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 239/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 240/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 241/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 242/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 243/250 | Ep. Total Reward: 8.0 | Epsilon : 0.041
# Episode 244/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 245/250 | Ep. Total Reward: 9.0 | Epsilon : 0.041
# Episode 246/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 247/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 248/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 249/250 | Ep. Total Reward: 10.0 | Epsilon : 0.041
# Episode 250/250 | Ep. Total Reward: 11.0 | Epsilon : 0.041
# Training time: 0.0003 seconds per episode

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]
plot_smoothed_training_rwd(train_reward_lst, window_size=20)
plot_eval_rwd_mean(eval_reward_mean_lst)
plot_eval_rwd_var(eval_reward_var_lst)
# Out:
# Warning: train_rwd_list has fewer elements (0) than window_size (20). Cannot compute moving average.

# %% [markdown]
# # DQN - Alternative
#
# You may insert extra cells in the notebook to perform tuning experiments and log results effectively. Use TensorBoard, plots, or tables to visualize the impact of different hyperparameter choices.

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]

# plot_smoothed_training_rwd(...

# plot_eval_rwd_mean(...

# plot_eval_rwd_var(...

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative DQN Policies

# %%
# [Write Code]

# %% [markdown]
# # DDQN

# %% [markdown]
# ## Define and Compile the Neural Networks
#
# The Double Deep Q-Network (DDQN) [https://arxiv.org/abs/1509.06461] improves upon standard DQN by reducing overestimation bias in Q-values. DDQN achieves this by decoupling action selection from value estimation using two networks, which is almost identical as DQN:
#
# - `target_model`: A periodically updated network that stabilizes training. During training, this network is used to compute $Q(S_{t+1}, a)$ for each possible action $a$. This network is also not trained but synced from `eval_model`. **However, unlike DQN, this network is only used to evaluate the Q-value of the action chosen by `eval_model`, making value updates more stable.**
#
# - `eval_model`: The online learning network that interacts with the environment. During training, this network is used to select the best action using $\arg\max_a Q(S_{t}, a)$ and updates its weights by minimizing the difference between predicted and target Q-value.
#
# The target used by DDQN is then:
#
# $Y^{Q}_t = R_{t+1} + \gamma Q_{target}(S_{t+1}, \arg \max_{a} Q_{eval}(S_{t+1}, a))$

# %%
# DDQN Baseline Model
from keras.models import Sequential
from keras.layers import Dense


# [WriteCode] from ... import ...
import os
import time
import numpy as np
import random
import gymnasium as gym
from collections import deque

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam 



# Define the eval (online) network
eval_model = Sequential()

# [WriteCode]
# model.add(...
eval_model.add(Dense(64, input_dim=4, activation='relu')) # 输入层 + 第一个隐藏层
eval_model.add(Dense(64, activation='relu'))      # 第二个隐藏层
eval_model.add(Dense(64, activation='relu'))           # 第三个隐藏层    
eval_model.add(Dense(2, activation='linear'))           # 输出层，输出每个动作的Q值
# Compile the model
# [WriteCode]
eval_model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
# Print the model summary
# [WriteCode]
print("--- Evaluation Model (Online Network) ---")
eval_model.summary()

# Create target_model with the same architecture
target_model = Sequential()

# [WriteCode]
# model.add(...
target_model.add(Dense(64, input_dim=4, activation='relu')) # 输入层 + 第一个隐藏层
target_model.add(Dense(64, activation='relu'))      # 第二个隐藏层
target_model.add(Dense(64, activation='relu'))           # 第三个隐藏层    
target_model.add(Dense(2, activation='linear'))           # 输出层，输出每个动作的Q值
# Skip compiling as target_model will not be trained with .fit()
# Instead, weights will be copied from the online model
# target_model.set_weights(eval_model.get_weights())

# Print the model summary
# [WriteCode]
print("\n--- Target Model ---")
target_model.summary()
# Out:
# --- Evaluation Model (Online Network) ---
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,770 (34.26 KB)
#  Trainable params: 8,770 (34.26 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Target Model ---
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,770 (34.26 KB)
#  Trainable params: 8,770 (34.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Use the following set of NN hyperparameters for ALL FOUR baseline policies
lr =  0.00025        #@param {type:"number"}               # learning rate
epochs =  1     #@param {type:"number"}               # epochs
episode = 250  #@param {type:"number"}               # episodes

epsilon = 1           #@param {type:"number"}     # Starting exploration rate
epsilon_min = 0.01    #@param {type:"number"}     # Exploration rate min
epsilon_decay = 0.995     #@param {type:"number"}     # Exploration rate decay

gamma = 0.99          #@param {type:"number"}     # Agent discount factor

# Use the following set of NN hyperparameters for Naive DQN, DQN and DDQN policies
ba =  32       #@param {type:"number"}               # batch_size

# Use the following set of RL hyperparameters for DQN and DDQN policies
target_update_freq = 100 # @param {type:"number"}    # Target network update frequency

# %% [markdown]
# ## Set Up Env and Train the Policy

# %%
# For logging
train_reward_lst = []
eval_reward_mean_lst = []
eval_reward_var_lst = []

# Set up environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0] # Number of observations (CartPole)
action_size = env.action_space.n            # Number of possible actions

model_dir = "ddqn_baseline"  # TensorBoard log directory
#cb = keras.callbacks.TensorBoard(log_dir = get_run_logdir(model_dir), histogram_freq=1)
# 【新代码】手动创建 TensorBoard 的 summary writer
logdir = get_run_logdir(model_dir)
summary_writer = tf.summary.create_file_writer(logdir + "/train")


# Train Counter for weight syncing
train_counter = 0

# For timing training
total_training_time = 0

# Define replay buffer
replay_buffer = deque(maxlen=10000)

for ep in range(episode):
    state, _ = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0

    # record start time
    start = time.time()

    for _ in range(500):

        # Interact with the environment with epsilon-greedy policy
        if np.random.rand() <= epsilon:
            action = np.random.choice(action_size)
        else:
            #pass # remove pass and use 2 lines below
            q_values = eval_model.predict(state, verbose=0)
            action = np.argmax(q_values)

        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        done = terminated or truncated

        # store experience into replay buffer
        # [WriteCode]
        store_experience(replay_buffer, state, action, reward, next_state, done)

        state = next_state
        total_reward += reward

        if done:
            break

        if len(replay_buffer) >= ba:
            train_counter += 1
            states, actions, rewards, next_states, dones = sample_experience(replay_buffer, ba)

            #下面几行是在构造训练目标标签
            # Update policy with mini-batches if replay buffer contains enough samples
            # Update policy using Double Deep Q-Learning update:
            # Q(s, a) = r + gamma * Q_target(S', argmax Q_eval(S', a))
            # [WriteCode]
            q_next_eval = eval_model.predict(next_states, verbose=0) # Shape: (batch_size, action_size)
            best_actions_next = np.argmax(q_next_eval, axis=1) # Shape: (batch_size,)
            q_next_target = target_model.predict(next_states, verbose=0)
            target_q_for_actions = q_next_target[range(ba), best_actions_next]  # Shape: (batch_size,)
            # Compute target Q-values:
            # - If done, Q-target = reward (no future reward)
            # - Otherwise, Q-target = reward + gamma * Q_target(S', argmax Q_eval(S', a))
            target_q_values = rewards + (gamma * target_q_for_actions * (1 - dones))

            # Predict current Q-values for state using eval_model
            # Use eval_model to determine best action in next_state
            # Use target_model to compute Q-value for that action
            current_q_values = eval_model.predict(states, verbose=0)
            target_for_fit = current_q_values
            
            # Update only the Q-value for the taken action
            target_for_fit[range(ba), actions] = target_q_values

            #目标标签构建好，将训练输入和目标传入fit函数中进行训练
            # Fit the model:
            # - Inputs: state
            # - Targets: updated Q-values (with action Q-value replaced by computed target)
            history = eval_model.fit(states, target_for_fit, epochs=1, verbose=0)  #这里训练一个epoch，其实就是上面那一个batch  # 不再需要 callbacks=[cb]
            # Update exploration rate
            # 【新代码】手动记录损失值
            loss = history.history['loss'][0]  # 从 history 对象中获取损失值

            # 【修改后代码】在这里记录 Loss 和 Average Q-Value
            # 计算当前批次状态的平均最大Q值
            avg_max_q = np.mean(np.max(current_q_values, axis=1))
            with summary_writer.as_default():
                tf.summary.scalar('batch_loss', data=loss, step=train_counter)
                tf.summary.scalar('average_max_q_value', data=avg_max_q, step=train_counter)

            if epsilon > epsilon_min:
                epsilon *= epsilon_decay

            # Periodically update the target network
            if train_counter % target_update_freq == 0:
               target_model.set_weights(eval_model.get_weights())

    # record end time and log training time
    end = time.time()
    total_training_time += end - start

    # Evaluation
    # [WriteCode]
    eval_reward_mean, eval_reward_var = evaluation(eval_model, max_timesteps=500)

    # 【修改后代码】在这里记录 Evaluation Reward
    with summary_writer.as_default():
        # 我们使用 episode 数量作为 x 轴，因为它在每个 episode 结束时才计算
        tf.summary.scalar('evaluation_reward_mean', data=eval_reward_mean, step=ep)
        # 也可以记录训练时的奖励，但评估奖励更具代表性
        tf.summary.scalar('training_episode_reward', data=total_reward, step=ep)

    print(f"Episode {ep + 1}/{episode} | Ep. Total Reward: {total_reward}"
        f" | Epsilon : {epsilon:.3f}"
        f" | Eval Rwd Mean: {eval_reward_mean:.2f}"
        f" | Eval Rwd Var: {eval_reward_var:.2f}")

    # Log
    eval_reward_mean_lst.append(eval_reward_mean)
    eval_reward_var_lst.append(eval_reward_var)
    train_reward_lst.append(total_reward)

    # Early Stopping Condition to avoid overfitting
    # If the evaluation reward reaches the specified threshold, stop training early.
    # The default threshold is set to 500, but you should adjust this based on observed training performance.
    if eval_reward_mean > 500: # [Modify this threshold as needed]
        print(f"Early stopping triggered at Episode {ep + 1}.")
        break

# record end time and calculate average training time per episode
# evaluate average training time per episode
print(f"Training time: {total_training_time/episode:.4f} seconds per episode")

env.close()
# Out:
# TensorBoard log directory: c:\Users\roycl\Desktop\EEC4400\eec4400_logs\ddqn_baseline\run_2025_11_06-17_04_18
# Episode 1/250 | Ep. Total Reward: 24.0 | Epsilon : 1.000 | Eval Rwd Mean: 50.80 | Eval Rwd Var: 99.76
# Episode 2/250 | Ep. Total Reward: 18.0 | Epsilon : 0.951 | Eval Rwd Mean: 11.20 | Eval Rwd Var: 19.36
# Episode 3/250 | Ep. Total Reward: 20.0 | Epsilon : 0.865 | Eval Rwd Mean: 42.20 | Eval Rwd Var: 134.16
# Episode 4/250 | Ep. Total Reward: 23.0 | Epsilon : 0.774 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 5/250 | Ep. Total Reward: 10.0 | Epsilon : 0.740 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.56
# Episode 6/250 | Ep. Total Reward: 17.0 | Epsilon : 0.683 | Eval Rwd Mean: 42.80 | Eval Rwd Var: 123.36
# Episode 7/250 | Ep. Total Reward: 19.0 | Epsilon : 0.624 | Eval Rwd Mean: 42.40 | Eval Rwd Var: 247.44
# Episode 8/250 | Ep. Total Reward: 16.0 | Epsilon : 0.579 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.56
# Episode 9/250 | Ep. Total Reward: 24.0 | Epsilon : 0.516 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 0.16
# Episode 10/250 | Ep. Total Reward: 12.0 | Epsilon : 0.488 | Eval Rwd Mean: 10.20 | Eval Rwd Var: 0.16
# Episode 11/250 | Ep. Total Reward: 10.0 | Epsilon : 0.467 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 12/250 | Ep. Total Reward: 30.0 | Epsilon : 0.404 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.64
# Episode 13/250 | Ep. Total Reward: 10.0 | Epsilon : 0.386 | Eval Rwd Mean: 8.80 | Eval Rwd Var: 0.56
# Episode 14/250 | Ep. Total Reward: 11.0 | Epsilon : 0.367 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.24
# Episode 15/250 | Ep. Total Reward: 12.0 | Epsilon : 0.347 | Eval Rwd Mean: 9.20 | Eval Rwd Var: 0.16
# Episode 16/250 | Ep. Total Reward: 10.0 | Epsilon : 0.332 | Eval Rwd Mean: 9.80 | Eval Rwd Var: 4.56
# Episode 17/250 | Ep. Total Reward: 10.0 | Epsilon : 0.317 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 18/250 | Ep. Total Reward: 16.0 | Epsilon : 0.294 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 19/250 | Ep. Total Reward: 9.0 | Epsilon : 0.283 | Eval Rwd Mean: 9.60 | Eval Rwd Var: 0.24
# Episode 20/250 | Ep. Total Reward: 15.0 | Epsilon : 0.264 | Eval Rwd Mean: 10.00 | Eval Rwd Var: 2.40
# Episode 21/250 | Ep. Total Reward: 14.0 | Epsilon : 0.247 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 22/250 | Ep. Total Reward: 9.0 | Epsilon : 0.237 | Eval Rwd Mean: 9.40 | Eval Rwd Var: 0.64
# Episode 23/250 | Ep. Total Reward: 16.0 | Epsilon : 0.220 | Eval Rwd Mean: 18.80 | Eval Rwd Var: 4.16
# Episode 24/250 | Ep. Total Reward: 21.0 | Epsilon : 0.199 | Eval Rwd Mean: 19.00 | Eval Rwd Var: 4.80
# Episode 25/250 | Ep. Total Reward: 19.0 | Epsilon : 0.182 | Eval Rwd Mean: 16.00 | Eval Rwd Var: 4.80
# Episode 26/250 | Ep. Total Reward: 17.0 | Epsilon : 0.168 | Eval Rwd Mean: 15.40 | Eval Rwd Var: 6.64
# Episode 27/250 | Ep. Total Reward: 15.0 | Epsilon : 0.157 | Eval Rwd Mean: 14.20 | Eval Rwd Var: 5.36
# Episode 28/250 | Ep. Total Reward: 26.0 | Epsilon : 0.138 | Eval Rwd Mean: 23.40 | Eval Rwd Var: 5.04
# Episode 29/250 | Ep. Total Reward: 15.0 | Epsilon : 0.129 | Eval Rwd Mean: 20.20 | Eval Rwd Var: 8.16
# Episode 30/250 | Ep. Total Reward: 30.0 | Epsilon : 0.111 | Eval Rwd Mean: 13.60 | Eval Rwd Var: 4.24
# Episode 31/250 | Ep. Total Reward: 30.0 | Epsilon : 0.096 | Eval Rwd Mean: 31.00 | Eval Rwd Var: 32.80
# Episode 32/250 | Ep. Total Reward: 21.0 | Epsilon : 0.087 | Eval Rwd Mean: 18.80 | Eval Rwd Var: 0.56
# Episode 33/250 | Ep. Total Reward: 50.0 | Epsilon : 0.068 | Eval Rwd Mean: 25.60 | Eval Rwd Var: 15.44
# Episode 34/250 | Ep. Total Reward: 54.0 | Epsilon : 0.052 | Eval Rwd Mean: 95.80 | Eval Rwd Var: 105.76
# Episode 35/250 | Ep. Total Reward: 31.0 | Epsilon : 0.045 | Eval Rwd Mean: 53.00 | Eval Rwd Var: 168.00
# Episode 36/250 | Ep. Total Reward: 50.0 | Epsilon : 0.035 | Eval Rwd Mean: 72.00 | Eval Rwd Var: 610.80
# Episode 37/250 | Ep. Total Reward: 29.0 | Epsilon : 0.031 | Eval Rwd Mean: 73.80 | Eval Rwd Var: 1691.76
# Episode 38/250 | Ep. Total Reward: 38.0 | Epsilon : 0.025 | Eval Rwd Mean: 27.20 | Eval Rwd Var: 4.16
# Episode 39/250 | Ep. Total Reward: 17.0 | Epsilon : 0.023 | Eval Rwd Mean: 88.40 | Eval Rwd Var: 211.84
# Episode 40/250 | Ep. Total Reward: 33.0 | Epsilon : 0.020 | Eval Rwd Mean: 90.40 | Eval Rwd Var: 32.64
# Episode 41/250 | Ep. Total Reward: 22.0 | Epsilon : 0.018 | Eval Rwd Mean: 100.00 | Eval Rwd Var: 54.80
# Episode 42/250 | Ep. Total Reward: 93.0 | Epsilon : 0.011 | Eval Rwd Mean: 105.00 | Eval Rwd Var: 132.80
# Episode 43/250 | Ep. Total Reward: 119.0 | Epsilon : 0.010 | Eval Rwd Mean: 92.40 | Eval Rwd Var: 87.04
# Episode 44/250 | Ep. Total Reward: 92.0 | Epsilon : 0.010 | Eval Rwd Mean: 91.40 | Eval Rwd Var: 83.04
# Episode 45/250 | Ep. Total Reward: 84.0 | Epsilon : 0.010 | Eval Rwd Mean: 96.80 | Eval Rwd Var: 149.36
# Episode 46/250 | Ep. Total Reward: 132.0 | Epsilon : 0.010 | Eval Rwd Mean: 145.40 | Eval Rwd Var: 174.64
# Episode 47/250 | Ep. Total Reward: 134.0 | Epsilon : 0.010 | Eval Rwd Mean: 108.00 | Eval Rwd Var: 142.00
# Episode 48/250 | Ep. Total Reward: 128.0 | Epsilon : 0.010 | Eval Rwd Mean: 173.40 | Eval Rwd Var: 556.24
# Episode 49/250 | Ep. Total Reward: 139.0 | Epsilon : 0.010 | Eval Rwd Mean: 144.80 | Eval Rwd Var: 82.96
# Episode 50/250 | Ep. Total Reward: 146.0 | Epsilon : 0.010 | Eval Rwd Mean: 136.80 | Eval Rwd Var: 18.56
# Episode 51/250 | Ep. Total Reward: 181.0 | Epsilon : 0.010 | Eval Rwd Mean: 196.40 | Eval Rwd Var: 232.64
# Episode 52/250 | Ep. Total Reward: 148.0 | Epsilon : 0.010 | Eval Rwd Mean: 152.00 | Eval Rwd Var: 150.80
# Episode 53/250 | Ep. Total Reward: 170.0 | Epsilon : 0.010 | Eval Rwd Mean: 167.00 | Eval Rwd Var: 136.80
# Episode 54/250 | Ep. Total Reward: 174.0 | Epsilon : 0.010 | Eval Rwd Mean: 178.40 | Eval Rwd Var: 83.84
# Episode 55/250 | Ep. Total Reward: 174.0 | Epsilon : 0.010 | Eval Rwd Mean: 172.60 | Eval Rwd Var: 401.04
# Episode 56/250 | Ep. Total Reward: 150.0 | Epsilon : 0.010 | Eval Rwd Mean: 244.40 | Eval Rwd Var: 1100.24
# Episode 57/250 | Ep. Total Reward: 206.0 | Epsilon : 0.010 | Eval Rwd Mean: 153.40 | Eval Rwd Var: 9.04
# Episode 58/250 | Ep. Total Reward: 179.0 | Epsilon : 0.010 | Eval Rwd Mean: 162.40 | Eval Rwd Var: 152.24
# Episode 59/250 | Ep. Total Reward: 205.0 | Epsilon : 0.010 | Eval Rwd Mean: 189.80 | Eval Rwd Var: 1224.96
# Episode 60/250 | Ep. Total Reward: 151.0 | Epsilon : 0.010 | Eval Rwd Mean: 178.00 | Eval Rwd Var: 914.00
# Episode 61/250 | Ep. Total Reward: 148.0 | Epsilon : 0.010 | Eval Rwd Mean: 148.80 | Eval Rwd Var: 137.36
# Episode 62/250 | Ep. Total Reward: 147.0 | Epsilon : 0.010 | Eval Rwd Mean: 150.80 | Eval Rwd Var: 47.76
# Episode 63/250 | Ep. Total Reward: 143.0 | Epsilon : 0.010 | Eval Rwd Mean: 126.20 | Eval Rwd Var: 24.56
# Episode 64/250 | Ep. Total Reward: 129.0 | Epsilon : 0.010 | Eval Rwd Mean: 140.00 | Eval Rwd Var: 28.40
# Episode 65/250 | Ep. Total Reward: 148.0 | Epsilon : 0.010 | Eval Rwd Mean: 185.60 | Eval Rwd Var: 112.64
# Episode 66/250 | Ep. Total Reward: 150.0 | Epsilon : 0.010 | Eval Rwd Mean: 135.80 | Eval Rwd Var: 36.56
# Episode 67/250 | Ep. Total Reward: 141.0 | Epsilon : 0.010 | Eval Rwd Mean: 169.60 | Eval Rwd Var: 448.24
# Episode 68/250 | Ep. Total Reward: 140.0 | Epsilon : 0.010 | Eval Rwd Mean: 132.00 | Eval Rwd Var: 60.40
# Episode 69/250 | Ep. Total Reward: 129.0 | Epsilon : 0.010 | Eval Rwd Mean: 114.80 | Eval Rwd Var: 12.16
# Episode 70/250 | Ep. Total Reward: 114.0 | Epsilon : 0.010 | Eval Rwd Mean: 105.40 | Eval Rwd Var: 16.24
# Episode 71/250 | Ep. Total Reward: 139.0 | Epsilon : 0.010 | Eval Rwd Mean: 138.40 | Eval Rwd Var: 173.84
# Episode 72/250 | Ep. Total Reward: 148.0 | Epsilon : 0.010 | Eval Rwd Mean: 165.80 | Eval Rwd Var: 209.36
# Episode 73/250 | Ep. Total Reward: 163.0 | Epsilon : 0.010 | Eval Rwd Mean: 162.60 | Eval Rwd Var: 59.84
# Episode 74/250 | Ep. Total Reward: 206.0 | Epsilon : 0.010 | Eval Rwd Mean: 150.80 | Eval Rwd Var: 186.16
# Episode 75/250 | Ep. Total Reward: 125.0 | Epsilon : 0.010 | Eval Rwd Mean: 185.20 | Eval Rwd Var: 425.36
# Episode 76/250 | Ep. Total Reward: 156.0 | Epsilon : 0.010 | Eval Rwd Mean: 148.20 | Eval Rwd Var: 155.76
# Episode 77/250 | Ep. Total Reward: 112.0 | Epsilon : 0.010 | Eval Rwd Mean: 115.60 | Eval Rwd Var: 23.44
# Episode 78/250 | Ep. Total Reward: 110.0 | Epsilon : 0.010 | Eval Rwd Mean: 143.20 | Eval Rwd Var: 42.16
# Episode 79/250 | Ep. Total Reward: 138.0 | Epsilon : 0.010 | Eval Rwd Mean: 158.60 | Eval Rwd Var: 151.04
# Episode 80/250 | Ep. Total Reward: 141.0 | Epsilon : 0.010 | Eval Rwd Mean: 192.40 | Eval Rwd Var: 389.44
# Episode 81/250 | Ep. Total Reward: 140.0 | Epsilon : 0.010 | Eval Rwd Mean: 158.60 | Eval Rwd Var: 32.24
# Episode 82/250 | Ep. Total Reward: 148.0 | Epsilon : 0.010 | Eval Rwd Mean: 171.40 | Eval Rwd Var: 304.64
# Episode 83/250 | Ep. Total Reward: 303.0 | Epsilon : 0.010 | Eval Rwd Mean: 192.80 | Eval Rwd Var: 1038.96
# Episode 84/250 | Ep. Total Reward: 111.0 | Epsilon : 0.010 | Eval Rwd Mean: 130.20 | Eval Rwd Var: 230.16
# Episode 85/250 | Ep. Total Reward: 131.0 | Epsilon : 0.010 | Eval Rwd Mean: 140.40 | Eval Rwd Var: 429.04
# Episode 86/250 | Ep. Total Reward: 125.0 | Epsilon : 0.010 | Eval Rwd Mean: 255.20 | Eval Rwd Var: 3332.56
# Episode 87/250 | Ep. Total Reward: 210.0 | Epsilon : 0.010 | Eval Rwd Mean: 161.00 | Eval Rwd Var: 154.40
# Episode 88/250 | Ep. Total Reward: 171.0 | Epsilon : 0.010 | Eval Rwd Mean: 227.00 | Eval Rwd Var: 4513.60
# Episode 89/250 | Ep. Total Reward: 207.0 | Epsilon : 0.010 | Eval Rwd Mean: 129.60 | Eval Rwd Var: 53.84
# Episode 90/250 | Ep. Total Reward: 140.0 | Epsilon : 0.010 | Eval Rwd Mean: 110.60 | Eval Rwd Var: 17.44
# Episode 91/250 | Ep. Total Reward: 149.0 | Epsilon : 0.010 | Eval Rwd Mean: 117.60 | Eval Rwd Var: 24.24
# Episode 92/250 | Ep. Total Reward: 117.0 | Epsilon : 0.010 | Eval Rwd Mean: 112.40 | Eval Rwd Var: 8.64
# Episode 93/250 | Ep. Total Reward: 125.0 | Epsilon : 0.010 | Eval Rwd Mean: 178.20 | Eval Rwd Var: 699.76
# Episode 94/250 | Ep. Total Reward: 143.0 | Epsilon : 0.010 | Eval Rwd Mean: 212.20 | Eval Rwd Var: 2359.76
# Episode 95/250 | Ep. Total Reward: 133.0 | Epsilon : 0.010 | Eval Rwd Mean: 222.80 | Eval Rwd Var: 6756.56
# Episode 96/250 | Ep. Total Reward: 270.0 | Epsilon : 0.010 | Eval Rwd Mean: 143.20 | Eval Rwd Var: 110.96
# Episode 97/250 | Ep. Total Reward: 166.0 | Epsilon : 0.010 | Eval Rwd Mean: 142.60 | Eval Rwd Var: 32.64
# Episode 98/250 | Ep. Total Reward: 189.0 | Epsilon : 0.010 | Eval Rwd Mean: 109.60 | Eval Rwd Var: 37.44
# Episode 99/250 | Ep. Total Reward: 142.0 | Epsilon : 0.010 | Eval Rwd Mean: 119.80 | Eval Rwd Var: 50.56
# Episode 100/250 | Ep. Total Reward: 134.0 | Epsilon : 0.010 | Eval Rwd Mean: 160.20 | Eval Rwd Var: 128.96
# Episode 101/250 | Ep. Total Reward: 186.0 | Epsilon : 0.010 | Eval Rwd Mean: 139.80 | Eval Rwd Var: 55.76
# Episode 102/250 | Ep. Total Reward: 151.0 | Epsilon : 0.010 | Eval Rwd Mean: 172.20 | Eval Rwd Var: 276.56
# Episode 103/250 | Ep. Total Reward: 178.0 | Epsilon : 0.010 | Eval Rwd Mean: 139.40 | Eval Rwd Var: 56.24
# Episode 104/250 | Ep. Total Reward: 147.0 | Epsilon : 0.010 | Eval Rwd Mean: 159.80 | Eval Rwd Var: 126.16
# Episode 105/250 | Ep. Total Reward: 153.0 | Epsilon : 0.010 | Eval Rwd Mean: 143.00 | Eval Rwd Var: 46.00
# Episode 106/250 | Ep. Total Reward: 274.0 | Epsilon : 0.010 | Eval Rwd Mean: 155.20 | Eval Rwd Var: 93.76
# Episode 107/250 | Ep. Total Reward: 206.0 | Epsilon : 0.010 | Eval Rwd Mean: 159.40 | Eval Rwd Var: 93.04
# Episode 108/250 | Ep. Total Reward: 157.0 | Epsilon : 0.010 | Eval Rwd Mean: 153.60 | Eval Rwd Var: 86.64
# Episode 109/250 | Ep. Total Reward: 163.0 | Epsilon : 0.010 | Eval Rwd Mean: 154.80 | Eval Rwd Var: 279.76
# Episode 110/250 | Ep. Total Reward: 163.0 | Epsilon : 0.010 | Eval Rwd Mean: 159.40 | Eval Rwd Var: 57.44
# Episode 111/250 | Ep. Total Reward: 155.0 | Epsilon : 0.010 | Eval Rwd Mean: 159.00 | Eval Rwd Var: 199.20
# Episode 112/250 | Ep. Total Reward: 126.0 | Epsilon : 0.010 | Eval Rwd Mean: 148.80 | Eval Rwd Var: 21.36
# Episode 113/250 | Ep. Total Reward: 146.0 | Epsilon : 0.010 | Eval Rwd Mean: 156.00 | Eval Rwd Var: 131.20
# Episode 114/250 | Ep. Total Reward: 128.0 | Epsilon : 0.010 | Eval Rwd Mean: 172.00 | Eval Rwd Var: 179.60
# Episode 115/250 | Ep. Total Reward: 153.0 | Epsilon : 0.010 | Eval Rwd Mean: 141.60 | Eval Rwd Var: 74.24
# Episode 116/250 | Ep. Total Reward: 137.0 | Epsilon : 0.010 | Eval Rwd Mean: 141.20 | Eval Rwd Var: 38.96
# Episode 117/250 | Ep. Total Reward: 166.0 | Epsilon : 0.010 | Eval Rwd Mean: 155.20 | Eval Rwd Var: 217.36
# Episode 118/250 | Ep. Total Reward: 164.0 | Epsilon : 0.010 | Eval Rwd Mean: 173.80 | Eval Rwd Var: 238.96
# Episode 119/250 | Ep. Total Reward: 163.0 | Epsilon : 0.010 | Eval Rwd Mean: 151.00 | Eval Rwd Var: 43.60
# Episode 120/250 | Ep. Total Reward: 169.0 | Epsilon : 0.010 | Eval Rwd Mean: 200.40 | Eval Rwd Var: 127.84
# Episode 121/250 | Ep. Total Reward: 138.0 | Epsilon : 0.010 | Eval Rwd Mean: 166.00 | Eval Rwd Var: 62.00
# Episode 122/250 | Ep. Total Reward: 163.0 | Epsilon : 0.010 | Eval Rwd Mean: 188.60 | Eval Rwd Var: 1469.04
# Episode 123/250 | Ep. Total Reward: 161.0 | Epsilon : 0.010 | Eval Rwd Mean: 193.20 | Eval Rwd Var: 1247.76
# Episode 124/250 | Ep. Total Reward: 191.0 | Epsilon : 0.010 | Eval Rwd Mean: 169.60 | Eval Rwd Var: 9.44
# Episode 125/250 | Ep. Total Reward: 140.0 | Epsilon : 0.010 | Eval Rwd Mean: 157.60 | Eval Rwd Var: 12.64
# Episode 126/250 | Ep. Total Reward: 167.0 | Epsilon : 0.010 | Eval Rwd Mean: 174.20 | Eval Rwd Var: 344.96
# Episode 127/250 | Ep. Total Reward: 132.0 | Epsilon : 0.010 | Eval Rwd Mean: 195.60 | Eval Rwd Var: 3505.84
# Episode 128/250 | Ep. Total Reward: 216.0 | Epsilon : 0.010 | Eval Rwd Mean: 182.60 | Eval Rwd Var: 148.64
# Episode 129/250 | Ep. Total Reward: 171.0 | Epsilon : 0.010 | Eval Rwd Mean: 168.60 | Eval Rwd Var: 115.44
# Episode 130/250 | Ep. Total Reward: 192.0 | Epsilon : 0.010 | Eval Rwd Mean: 151.20 | Eval Rwd Var: 70.96
# Episode 131/250 | Ep. Total Reward: 155.0 | Epsilon : 0.010 | Eval Rwd Mean: 154.00 | Eval Rwd Var: 59.20
# Episode 132/250 | Ep. Total Reward: 168.0 | Epsilon : 0.010 | Eval Rwd Mean: 156.20 | Eval Rwd Var: 81.36
# Episode 133/250 | Ep. Total Reward: 149.0 | Epsilon : 0.010 | Eval Rwd Mean: 173.20 | Eval Rwd Var: 285.76
# Episode 134/250 | Ep. Total Reward: 149.0 | Epsilon : 0.010 | Eval Rwd Mean: 164.00 | Eval Rwd Var: 116.40
# Episode 135/250 | Ep. Total Reward: 189.0 | Epsilon : 0.010 | Eval Rwd Mean: 170.20 | Eval Rwd Var: 75.36
# Episode 136/250 | Ep. Total Reward: 157.0 | Epsilon : 0.010 | Eval Rwd Mean: 175.60 | Eval Rwd Var: 47.04
# Episode 137/250 | Ep. Total Reward: 204.0 | Epsilon : 0.010 | Eval Rwd Mean: 226.40 | Eval Rwd Var: 1985.44
# Episode 138/250 | Ep. Total Reward: 186.0 | Epsilon : 0.010 | Eval Rwd Mean: 206.80 | Eval Rwd Var: 1156.96
# Episode 139/250 | Ep. Total Reward: 176.0 | Epsilon : 0.010 | Eval Rwd Mean: 179.20 | Eval Rwd Var: 648.16
# Episode 140/250 | Ep. Total Reward: 165.0 | Epsilon : 0.010 | Eval Rwd Mean: 168.60 | Eval Rwd Var: 46.24
# Episode 141/250 | Ep. Total Reward: 149.0 | Epsilon : 0.010 | Eval Rwd Mean: 164.80 | Eval Rwd Var: 272.96
# Episode 142/250 | Ep. Total Reward: 194.0 | Epsilon : 0.010 | Eval Rwd Mean: 186.20 | Eval Rwd Var: 268.96
# Episode 143/250 | Ep. Total Reward: 206.0 | Epsilon : 0.010 | Eval Rwd Mean: 161.80 | Eval Rwd Var: 350.96
# Episode 144/250 | Ep. Total Reward: 210.0 | Epsilon : 0.010 | Eval Rwd Mean: 198.40 | Eval Rwd Var: 385.04
# Episode 145/250 | Ep. Total Reward: 185.0 | Epsilon : 0.010 | Eval Rwd Mean: 234.40 | Eval Rwd Var: 4066.24
# Episode 146/250 | Ep. Total Reward: 234.0 | Epsilon : 0.010 | Eval Rwd Mean: 212.80 | Eval Rwd Var: 797.76
# Episode 147/250 | Ep. Total Reward: 212.0 | Epsilon : 0.010 | Eval Rwd Mean: 178.00 | Eval Rwd Var: 560.00
# Episode 148/250 | Ep. Total Reward: 157.0 | Epsilon : 0.010 | Eval Rwd Mean: 252.60 | Eval Rwd Var: 1246.64
# Episode 149/250 | Ep. Total Reward: 305.0 | Epsilon : 0.010 | Eval Rwd Mean: 192.40 | Eval Rwd Var: 691.04
# Episode 150/250 | Ep. Total Reward: 179.0 | Epsilon : 0.010 | Eval Rwd Mean: 178.40 | Eval Rwd Var: 310.64
# Episode 151/250 | Ep. Total Reward: 187.0 | Epsilon : 0.010 | Eval Rwd Mean: 180.80 | Eval Rwd Var: 413.36
# Episode 152/250 | Ep. Total Reward: 214.0 | Epsilon : 0.010 | Eval Rwd Mean: 192.00 | Eval Rwd Var: 304.80
# Episode 153/250 | Ep. Total Reward: 253.0 | Epsilon : 0.010 | Eval Rwd Mean: 438.00 | Eval Rwd Var: 15376.00
# Episode 154/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 495.80 | Eval Rwd Var: 48.96
# Episode 155/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 457.60 | Eval Rwd Var: 202.64
# Episode 156/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 402.80 | Eval Rwd Var: 15612.16
# Episode 157/250 | Ep. Total Reward: 276.0 | Epsilon : 0.010 | Eval Rwd Mean: 331.40 | Eval Rwd Var: 10815.04
# Episode 158/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 350.80 | Eval Rwd Var: 3310.16
# Episode 159/250 | Ep. Total Reward: 253.0 | Epsilon : 0.010 | Eval Rwd Mean: 500.00 | Eval Rwd Var: 0.00
# Episode 160/250 | Ep. Total Reward: 170.0 | Epsilon : 0.010 | Eval Rwd Mean: 169.40 | Eval Rwd Var: 5.44
# Episode 161/250 | Ep. Total Reward: 260.0 | Epsilon : 0.010 | Eval Rwd Mean: 153.40 | Eval Rwd Var: 63.04
# Episode 162/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 206.00 | Eval Rwd Var: 588.80
# Episode 163/250 | Ep. Total Reward: 186.0 | Epsilon : 0.010 | Eval Rwd Mean: 141.60 | Eval Rwd Var: 117.84
# Episode 164/250 | Ep. Total Reward: 125.0 | Epsilon : 0.010 | Eval Rwd Mean: 118.40 | Eval Rwd Var: 19.84
# Episode 165/250 | Ep. Total Reward: 67.0 | Epsilon : 0.010 | Eval Rwd Mean: 130.00 | Eval Rwd Var: 18.80
# Episode 166/250 | Ep. Total Reward: 75.0 | Epsilon : 0.010 | Eval Rwd Mean: 48.60 | Eval Rwd Var: 2087.44
# Episode 167/250 | Ep. Total Reward: 85.0 | Epsilon : 0.010 | Eval Rwd Mean: 122.60 | Eval Rwd Var: 23.44
# Episode 168/250 | Ep. Total Reward: 383.0 | Epsilon : 0.010 | Eval Rwd Mean: 204.00 | Eval Rwd Var: 331.20
# Episode 169/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 500.00 | Eval Rwd Var: 0.00
# Episode 170/250 | Ep. Total Reward: 500.0 | Epsilon : 0.010 | Eval Rwd Mean: 500.00 | Eval Rwd Var: 0.00
# Episode 171/250 | Ep. Total Reward: 371.0 | Epsilon : 0.010 | Eval Rwd Mean: 500.00 | Eval Rwd Var: 0.00

# %% [markdown]
# ## Plot Results

# %%
# Write code to plot
# 1) Moving Averaged Training Reward, 2) Evaluation Mean, 3) Evaluation Variance
# [Write Code]
print("--- Plotting Results for DDQN Baseline Model ---")
plot_smoothed_training_rwd(train_reward_lst, window_size=20)

plot_eval_rwd_mean(eval_reward_mean_lst)

plot_eval_rwd_var(eval_reward_var_lst)
# Out:
# --- Plotting Results for DDQN Baseline Model ---
# Warning: train_rwd_list has fewer elements (5) than window_size (20). Cannot compute moving average.

# %% [markdown]
# # DDQN - Alternative
#
# You may insert extra cells in the notebook to perform tuning experiments and log results effectively. Use TensorBoard, plots, or tables to visualize the impact of different hyperparameter choices.

# %%
# [Write Code]

# %% [markdown]
# ## Comparison
#
# Compare performance of the Baseline and the Alternative DDQN Policies

# %%
# [Write Code]

# %% [markdown]
# # Visualize with Tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./eec4400_logs --port=6006

# %% [markdown]
# # Comparison Across Four Alternative Policies
#
# Compare hyperparameters and performance of the four alternative policies.
#
# You may insert extra cells in the notebook to tabulate/plot/log results effectively.

# %%
# [Write Code]
